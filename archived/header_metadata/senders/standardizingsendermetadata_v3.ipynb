# %%
import re
f = open("alldeq14.txt", "r+")
deqsstr = f.read()
#deqslist = re.split("\n", deqsstr)

# %%
deqslist= re.findall("deq14.b1.*", deqsstr)
#deqslist = '\n'.join(deqssample)
#print(deqssample)
#len(deqssample)

# %%
from urllib import request

emailstext = ''

s3_root = "https://flint-text.s3.amazonaws.com/"
for deq in deqslist:       
    url = s3_root + deq
    response = request.urlopen(url)
    raw_text = response.read().decode('utf8')
    emailstext = "".join((raw_text, emailstext)) #changed this line

# %%
#print(emailstext) #see full email output

# %%
froms = re.findall("From:.[A-Za-z].*", emailstext)
fromstr = '\n'.join(froms)
fromstr_orgs = re.sub("From:\W","", fromstr) #with (ORG)
fromstr_noorgs = re.sub("[(].*[)]","", fromstr_orgs)#without (ORG)
fromstr_noemail1 = re.sub("[<].*[>]*","", fromstr_noorgs)
fromstr_noemail2 = re.sub("[{].*[}]*","", fromstr_noemail1)
fromstr_noemail3 = re.sub("\[.*\]*","", fromstr_noemail2)
fromstr_noendspace1 = re.sub("\s+\n","\n", fromstr_noemail3)
fromstr_noendspace2 = re.sub("\s$","",fromstr_noendspace1)
print(fromstr_noendspace2)
# Out:
# Waurfel, Brad
# Murray, David
# Lea Moste
# Crooks, Jennifer
# Prysby, Mike
# Benzie, Richard
# Busch, Stephen
# Prysby, Mike
# Michael Glasgow
# Wurfel, Brad
# Rennaker, Joanne
# Benzie, Richard
# Devereaux, Tracy Jo
# Benzie, Richard
# Rosenthal, Adam
# Benzie, Richard
# Ostrander, Debbie
# Rosenthal, Adam
# Benzie, Richard
# Rosenthal, Adam
# Bennett, Charles
# DTMB Facilities
# Brewster, Simone
# Rosenthal, Adam
# Shekter Smith, Liane
# Jacquelyn Boven
# Wurfel, Brad
# Kevin Forbes
# Michael Glasgow
# Michael Glasgow
# Busch, Stephen
# Tommasulo, Karen
# Rosenthal, Adam
# Prysby, Mike
# Busch, Stephen
# Rosenthal, Adam
# Michael Glasgow
# Rosenthal, Adam
# Michael Glasgow
# Rosenthal, Adam HECY
# Deltoral, Miguel
# Marc Edwards
# Fortin, Denise
# Damato, Nicholas
# Wurfel, Brad
# Busch, Stephen
# Prysby, Mike
# Busch, Stephen
# Ostrander, Debbie
# Crooks, Jennifer
# Crooks, Jennifer
# Rosenthal, Adam
# Michael Glasgow
# Rosenthal, Adam
# Michael Glasgow
# Wurfel, Brad
# Lindsey Smith
# Deltoral, Miguel
# Marc Edwards
# Fortln, Denise
# Damato, Nicholas
# Shekter Smith, Liane
# Hyde, Tinka
# Shekter Smith, Liane
# Hyde, Tinka
# Wurfel, Brad
# Curt Guyette
# Wurfel, Brad
# Shekter Smith, Liane
# Jennifer Crooks
# Poy, Thomas
# Crooks, Jennifer
# Porter, Andrea
# Shekter Smith, Liane
# Poy, Thomas
# Shekter Smith, Liane
# Hyde, Tinka
# Busch, Stephen
# Rosenthal, Adam
# Marc Edwards
# Marc Edwards
# Prysby, Mike
# Busch, Stephen
# Workman, Wayne
# Byrne, Randall
# Natasha Henderson
# Murray, David
# Workman, Wayne
# Byrne, Randall
# Natasha Henderson
# Marc Edwards
# Marc Edwards
# Holton, Jennifer
# Lasher, Geralyn
# Wurfel, Brad
# Lasher, Geralyn

# %%
ons = re.findall("On.*wrote", emailstext)
onstr = '\n'.join(ons)
onstr1 = re.sub("On\s.*at\s[0-9]*:[0-9][0-9]\s[AP]M\W*","", onstr)
onstr2 = re.sub("wrote","",onstr1)
onstr_noorgs = re.sub("[(].*[)]","", onstr1)
onstr_noemail1 = re.sub("[<].*[>]*","", onstr_noorgs)
onstr_noemail2 = re.sub("\[.*\]*","", onstr_noemail1)
onstr_noemail3 = re.sub("[{].*[}]*","", onstr_noemail2)
onstr_noquotes = re.sub("\"","", onstr_noemail3)
onstr_noendspace1 = re.sub("\s+\n","\n", onstr_noquotes)
onstr_noendspace2 = re.sub("\s+$","", onstr_noendspace1)
print(onstr_noendspace2)
# Out:
# Michael Glasgow
# Lea Moste
# Michael Glasgow
# Rosenthal, Adam
# Rosenthal, Adam
# Rosenthal, Adam
# Rosenthal, Adam
# Rosenthal, Adam
# Shekter Smith, Liane
# Prysby, Mike
# Cook, Pat
# Rosenthal, Adam
# Wurfel, Brad
# Shekter Smith, Liane
# Kaffer, Nancy
# Wurfel, Sara
# Wurfel, Brad
# Alexandra Billings
# Livengood, Chad
# Wurfel, Brad
# Busch, Stephen
# Devereaux, Tracy Jo
# Wurfel, Brad
# Wurfel, Brad
# Jacob Kanclerz
# Wyant, Dan
# Wurfel, Brad
# Murray, David
# Kaffer, Nancy
# Kaffer, Nancy
# Wurfel, Brad
# Gary Wilson
# Macaluso, Nora
# Wurfel, Brad
# Lindsey Smith

# %%
roughlist = []
fromsenders = re.split('\n', fromstr_noendspace2) #splits from str into list
onsenders = re.split('\n',onstr_noendspace2) #splits on... str into list

#combines the two lists; roughlist contains names found in From: header and On... header
roughlist.extend(onsenders)
roughlist.extend(fromsenders)

roughstr = '\n'.join(roughlist) #makes list into string
print("rough list of " + str(len(roughlist)) + " things that might be names:")
print("- - -")
print(roughstr)
# Out:
# rough list of 421 things that might be names:
# - - -
# Michael Glasgow
# Lea Moste
# Michael Glasgow
# Rosenthal, Adam
# Rosenthal, Adam
# Rosenthal, Adam
# Rosenthal, Adam
# Rosenthal, Adam
# Shekter Smith, Liane
# Prysby, Mike
# Cook, Pat
# Rosenthal, Adam
# Wurfel, Brad
# Shekter Smith, Liane
# Kaffer, Nancy
# Wurfel, Sara
# Wurfel, Brad
# Alexandra Billings
# Livengood, Chad
# Wurfel, Brad
# Busch, Stephen
# Devereaux, Tracy Jo
# Wurfel, Brad
# Wurfel, Brad
# Jacob Kanclerz
# Wyant, Dan
# Wurfel, Brad
# Murray, David
# Kaffer, Nancy
# Kaffer, Nancy
# Wurfel, Brad
# Gary Wilson
# Macaluso, Nora
# Wurfel, Brad
# Lindsey Smith
# Waurfel, Brad
# Wurfel, Brad
# Busch, Stephen
# Wurfel, Brad
# Wurfel, Brad
# Thelen, Mary Beth
# Wurfel, Brad
# Wurfel, Brad
# Tommasulo, Karen
# Wurfel, Brad
# Wurfel, Brad
# Busch, Stephen
# Wurfel, Brad
# Waurfel, Brad
# Dalebout, Rick
# Wurfel, Brad
# Wurfel, Brad
# Stephen Carmody
# Kaffer, Nancy
# Wurfel, Brad
# Wurfel, Brad
# Wurfel, Brad
# Wurfel, Brad
# Saxton, Thomas
# Busch, Stephen
# Wurfel, Brad
# Rosenthal, Adam
# Marc Edwards
# Marc Edwards
# Curt Guyette
# Wurfel, Brad
# Busch, Stephen
# Busch, Stephen
# Wurfel, Sara
# Jason Lorenz
# do-not-reply@detroitnews.com
# Wurfel, Brad
# Muchmore, Dennis
# Wurfel, Brad
# Muchmore, Dennis
# Wurfel, Brad
# Wurfel, Brad
# Waurfel, Brad
# Waurfel, Brad
# Wurfel, Brad
# Feuerstein, Heather
# Waurfel, Brad
# Pallone, Maggie
# Ronald Fonger
# Ronald Fonger
# Wurfel, Brad
# Wurfel, Brad
# Wurfel, Brad
# Ronald Fonger
# Wurfel, Sara
# Wurfel, Brad
# Wurfel, Sara
# Wurfel, Sara
# Wurfel, Brad
# Jacob Kanclerz
# Wurfel, Sara
# Wurfel, Sara
# Ronald Fonger
# Wurfel, Brad
# Wurfel, Brad
# GOV Newsroom
# Gary Wilson
# Holton, Jennifer
# Holton, Jennifer
# Holton, Jennifer
# Danielle Emerson
# Wurfel, Brad
# Danielle Emerson
# Danielle Emerson
# Macaluso, Nora
# Wurfel, Brad
# Angela Wittrock
# Lindsey Smith
# Angela Wittrock
# Danielle Emerson
# Angela Wittrock
# Wurfel, Brad
# Saxton, Thomas
# Minicuci, Angela
# Egan, Paul
# Bryan Hill
# Holton, Jennifer
# Holton, Jennifer
# Ockert, Katherine
# Sameen Amin
# Muchmore, Dennis
# Workman, Wayne
# Byrne, Randall
# Natasha Henderson
# Murray, David
# Workman, Wayne
# Byrne, Randall
# Natasha Henderson
# Marc Edwards
# Marc Edwards
# Holton, Jennifer
# Lasher, Geralyn
# Wurfel, Brad
# Lasher, Geralyn

# %%
ultimatelist = [] #creates final list for final sender names to be put into

# %%
# extracts sender lines formatted in [Last, First] 
lastcommafirstdude = re.findall("[A-Z][a-z]*.[A-Za-z]+,\s[A-Z][a-z][A-Za-z]+.*",roughstr)
ultimatelist.extend(lastcommafirstdude) #puts these names into ultimatelist
print(lastcommafirstdude)
len(lastcommafirstdude) #number of names already in LAST, FIRST format
# Out:
# ['Rosenthal, Adam', 'Rosenthal, Adam', 'Rosenthal, Adam', 'Rosenthal, Adam', 'Rosenthal, Adam', 'Shekter Smith, Liane', 'Prysby, Mike', 'Cook, Pat', 'Rosenthal, Adam', 'Wurfel, Brad', 'Shekter Smith, Liane', 'Kaffer, Nancy', 'Wurfel, Sara', 'Wurfel, Brad', 'Livengood, Chad', 'Wurfel, Brad', 'Busch, Stephen', 'Devereaux, Tracy Jo', 'Wurfel, Brad', 'Wurfel, Brad', 'Wyant, Dan', 'Wurfel, Brad', 'Murray, David', 'Kaffer, Nancy', 'Kaffer, Nancy', 'Wurfel, Brad', 'Macaluso, Nora', 'Wurfel, Brad', 'Waurfel, Brad', 'Murray, David', 'Crooks, Jennifer', 'Prysby, Mike', 'Benzie, Richard', 'Busch, Stephen', 'Prysby, Mike', 'Wurfel, Brad', 'Rennaker, Joanne', 'Benzie, Richard', 'Devereaux, Tracy Jo', 'Benzie, Richard', 'Rosenthal, Adam', 'Benzie, Richard', 'Ostrander, Debbie', 'Rosenthal, Adam', 'Benzie, Richard', 'Rosenthal, Adam', 'Bennett, Charles', 'Brewster, Simone', 'Rosenthal, Adam', 'Shekter Smith, Liane', 'Wurfel, Brad', 'Busch, Stephen', 'Tommasulo, Karen', 'Rosenthal, Adam', 'Prysby, Mike', 'Busch, Stephen', 'Rosenthal, Adam', 'Rosenthal, Adam', 'Rosenthal, Adam HECY', 'Deltoral, Miguel', 'Fortin, Denise', 'Damato, Nicholas', 'Wurfel, Brad', 'Busch, Stephen', 'Prysby, Mike', 'Busch, Stephen', 'Ostrander, Debbie', 'Crooks, Jennifer', 'Crooks, Jennifer', 'Rosenthal, Adam', 'Rosenthal, Adam', 'Wurfel, Brad', 'Deltoral, Miguel', 'Fortln, Denise', 'Damato, Nicholas', 'Shekter Smith, Liane', 'Hyde, Tinka', 'Shekter Smith, Liane', 'Hyde, Tinka', 'Wurfel, Brad', 'Wurfel, Brad', 'Shekter Smith, Liane', 'Poy, Thomas', 'Crooks, Jennifer', 'Porter, Andrea', 'Shekter Smith, Liane', 'Poy, Thomas', 'Shekter Smith, Liane', 'Hyde, Tinka', 'Busch, Stephen', 'Rosenthal, Adam', 'Prysby, Mike', 'Busch, Stephen', 'Prysby, Mike', 'Wurfel, Brad', 'Prysby, Mike', 'Benzie, Richard', 'Prysby, Mike', 'Cook, Pat', 'Prysby, Mike', 'Busch, Stephen', 'Prysby, Mike', 'Benzie, Richard', 'Busch, Stephen', 'Rosenthal, Adam', 'Busch, Stephen', 'Benzie, Richard', 'Poy, Thomas', 'Benzie, Richard', 'Busch, Stephen', 'Wurfel, Brad', 'Rosenthal, Adam', 'Rosenthal, Adam', 'Poy, Thomas', 'Rosenthal, Adam', 'Poy, Thomas', 'Shoven, Heather', 'Crooks, Jennifer', 'Prysby, Mike', 'Rosenthal, Adam', 'Busch, Stephen', 'Busch, Stephen', 'Warfel, Brad', 'Wurfel, Brad', 'Sygo, Jim', 'Wurfel, Brad', 'Shekter Smith, Llane', 'Wurfel, Brad', 'Whrfel, Brad', 'Tommasulo, Karen', 'Wurfel, Brad', 'Shekter Smith, Llane', 'Shaler, Karen', 'Shaler, Karen', 'Shaler, Karen', 'Shekter Smith, Liane', 'Hyde, Tinka', 'Crooks, Jennifer', 'Busch, Stephen', 'Krisztian, George', 'Wurfel, Brad', 'Shekter, Jean', 'Rosenthal, Adam', 'Shekter, Jean', 'Rosenthal, Adam', 'Rosenthal, Adam', 'Benzie, Richard', 'Busch, Stephen', 'Wurfel, Brad', 'Wurfel, Sara', 'Eisner, Jennifer', 'Wurfel, Sara', 'Buhs, Caleb', 'Pratt, Jeff', 'Wurfel, Brad', 'Kaffer, Nancy', 'Kaffer, Nancy', 'Wurfel, Sara', 'Kaffer, Nancy', 'Kaffer, Nancy', 'Wurfel, Brad', 'Wurfel, Sara', 'Wurfel, Brad', 'Wurfel, Brad', 'Wurfel, Sara', 'Wurfel, Sara', 'Kaffer, Nancy', 'Wurfel, Sara', 'Waurfel, Brad', 'Wurfel, Brad', 'Waurfel, Brad', 'Wurfel, Brad', 'Wurfel, Brad', 'Murray, David', 'Wurfel, Brad', 'Wurfel, Brad', 'Wurfel, Brad', 'Wurfel, Brad', 'Pallone, Maggie', 'Pallone, Maggie', 'Shekter Smith, Liane', 'Benzie, Richard', 'Busch, Stephen', 'Pallone, Maggie', 'Busch, Stephen', 'Wurfel, Brad', 'Grijalva, Nancy', 'Anderson, Paula', 'Miller, Mark', 'Anderson, Paula', 'Dykema, Linda D.', 'Peeler, Nancy', 'Busch, Stephen', 'Wurfel, Brad', 'Busch, Stephen', 'Wurfel, Brad', 'Busch, Stephen', 'Wurfel, Brad', 'Busch, Stephen', 'Busch, Stephen', 'Wurfel, Brad', 'Wurfel, Sara', 'Wurfel, Brad', 'Wurfel, Brad', 'Wurfel, Brad', 'Wurfel, Brad', 'Waurfel, Brad', 'Wurfel, Brad', 'Saxton, Thomas', 'Waurfel, Brad', 'Wurfel, Brad', 'Shoven, Heather', 'Wurfel, Brad', 'Wurfel, Brad', 'Wurfel, Brad', 'Wurfel, Brad', 'Wurfel, Brad', 'Busch, Stephen', 'Wurfel, Brad', 'Wurfel, Brad', 'Muchmore, Dennis', 'Wurfel, Brad', 'Shekter Smith, Liane', 'Busch, Stephen', 'Brown, Je ...
# 326

# %%
# extracts sender lines formatted in [First Last] 
firstlast = re.findall("[A-Z][a-z]+.[A-Z][a-z][A-Za-z]+",roughstr)
#print(firstlast)

# %%
#problem: for "Shekter Smith, Liane", "Shekter Smith" is read as a [First Last]
#band-aid solution:
unwanted = {'Shekter Smith', 'Mary Beth'}
firstlast1 = [e for e in firstlast if e not in unwanted]
firstlaststring = '\n'.join(firstlast1)
print(firstlaststring)
# Out:
# Michael Glasgow
# Lea Moste
# Michael Glasgow
# Alexandra Billings
# Jacob Kanclerz
# Gary Wilson
# Lindsey Smith
# Lea Moste
# Michael Glasgow
# Jacquelyn Boven
# Kevin Forbes
# Michael Glasgow
# Michael Glasgow
# Michael Glasgow
# Michael Glasgow
# Marc Edwards
# Michael Glasgow
# Michael Glasgow
# Lindsey Smith
# Marc Edwards
# Curt Guyette
# Jennifer Crooks
# Marc Edwards
# Marc Edwards
# Curt Guyette
# Marc Edwards
# Lindsey Smith
# Michael Glasgow
# Michael Glasgow
# Michael Glasgow
# Marc Edwards
# Marc Edwards
# Curt Guyette
# Curt Guyette
# Ronald Fonger
# Jean Shekter
# Alexandra Billings
# Alexandra Billings
# Christopher Klaver
# Ronald Fonger
# Ronald Fonger
# Ronald Fonger
# Ronald Fonger
# Curt Guyette
# Ronald Fonger
# Ronald Fonger
# Ronald Fonger
# Ronald Fonger
# Ronald Fonger
# Jason Lorenz
# Stephen Carmody
# Stephen Carmody
# Ronald Fonger
# Arthur Woodson
# Ronald Fonger
# Ronald Fonger
# Ronald Fonger
# Ronald Fonger
# Ronald Fonger
# Ronald Fonger
# Jason Lorenz
# Jacob Kanclerz
# Progress Michigan
# Ronald Fonger
# Jason Lorenz
# Jason Lorenz
# Stephen Carmody
# Marc Edwards
# Marc Edwards
# Curt Guyette
# Jason Lorenz
# Ronald Fonger
# Ronald Fonger
# Ronald Fonger
# Jacob Kanclerz
# Ronald Fonger
# Gary Wilson
# Danielle Emerson
# Danielle Emerson
# Danielle Emerson
# Angela Wittrock
# Lindsey Smith
# Angela Wittrock
# Danielle Emerson
# Angela Wittrock
# Bryan Hill
# Sameen Amin
# Natasha Henderson
# Natasha Henderson
# Marc Edwards
# Marc Edwards

# %%
#LIST OF ALL NAMES (FIRST LAST FIRST LAST etc.)
allflnames = re.findall('[A-Z][a-z][A-Za-z]+',firstlaststring)
#print(allflnames)
#len(allflnames)

# %%
#LIST OF FIRST NAMES
firstnames = re.findall('^[A-Z][a-z]+\s|\n[A-Z][a-z]+\s',firstlaststring)
firstnames1 = ' '.join(firstnames)
firstnames2 = re.sub("\n","",firstnames1)
firstnameslist = re.split("\s+",firstnames2)
firstnameslist.pop()
print("first names:")
print(firstnameslist)
print("")

#LIST OF LAST NAMES
lastnames1 = re.findall('.[A-Z][a-z]+',firstlaststring)
lastnames2 = ''.join(lastnames1)
lastnameslist = re.split('\s',lastnames2)
del lastnameslist[0]
print("last names:")
print(lastnameslist)
#print(" ")
#if len(lastnameslist) == len(firstnameslist):
    #print("yay, there are " + str(len(lastnameslist)) + " first and last names.")
#else:
    #print("drat! the number of first names found doesn't match the number of last names found")
# Out:
# first names:
# ['Michael', 'Lea', 'Michael', 'Alexandra', 'Jacob', 'Gary', 'Lindsey', 'Lea', 'Michael', 'Jacquelyn', 'Kevin', 'Michael', 'Michael', 'Michael', 'Michael', 'Marc', 'Michael', 'Michael', 'Lindsey', 'Marc', 'Curt', 'Jennifer', 'Marc', 'Marc', 'Curt', 'Marc', 'Lindsey', 'Michael', 'Michael', 'Michael', 'Marc', 'Marc', 'Curt', 'Curt', 'Ronald', 'Jean', 'Alexandra', 'Alexandra', 'Christopher', 'Ronald', 'Ronald', 'Ronald', 'Ronald', 'Curt', 'Ronald', 'Ronald', 'Ronald', 'Ronald', 'Ronald', 'Jason', 'Stephen', 'Stephen', 'Ronald', 'Arthur', 'Ronald', 'Ronald', 'Ronald', 'Ronald', 'Ronald', 'Ronald', 'Jason', 'Jacob', 'Progress', 'Ronald', 'Jason', 'Jason', 'Stephen', 'Marc', 'Marc', 'Curt', 'Jason', 'Ronald', 'Ronald', 'Ronald', 'Jacob', 'Ronald', 'Gary', 'Danielle', 'Danielle', 'Danielle', 'Angela', 'Lindsey', 'Angela', 'Danielle', 'Angela', 'Bryan', 'Sameen', 'Natasha', 'Natasha', 'Marc', 'Marc']
#
# last names:
# ['Glasgow', 'Moste', 'Glasgow', 'Billings', 'Kanclerz', 'Wilson', 'Smith', 'Moste', 'Glasgow', 'Boven', 'Forbes', 'Glasgow', 'Glasgow', 'Glasgow', 'Glasgow', 'Edwards', 'Glasgow', 'Glasgow', 'Smith', 'Edwards', 'Guyette', 'Crooks', 'Edwards', 'Edwards', 'Guyette', 'Edwards', 'Smith', 'Glasgow', 'Glasgow', 'Glasgow', 'Edwards', 'Edwards', 'Guyette', 'Guyette', 'Fonger', 'Shekter', 'Billings', 'Billings', 'Klaver', 'Fonger', 'Fonger', 'Fonger', 'Fonger', 'Guyette', 'Fonger', 'Fonger', 'Fonger', 'Fonger', 'Fonger', 'Lorenz', 'Carmody', 'Carmody', 'Fonger', 'Woodson', 'Fonger', 'Fonger', 'Fonger', 'Fonger', 'Fonger', 'Fonger', 'Lorenz', 'Kanclerz', 'Michigan', 'Fonger', 'Lorenz', 'Lorenz', 'Carmody', 'Edwards', 'Edwards', 'Guyette', 'Lorenz', 'Fonger', 'Fonger', 'Fonger', 'Kanclerz', 'Fonger', 'Wilson', 'Emerson', 'Emerson', 'Emerson', 'Wittrock', 'Smith', 'Wittrock', 'Emerson', 'Wittrock', 'Hill', 'Amin', 'Henderson', 'Henderson', 'Edwards', 'Edwards']

# %%
print("Reformatted names:")
print("- - -")
for idx, value in enumerate(firstnameslist):
    key = lastnameslist[idx] + ", " + firstnameslist[idx]
    print(key)
    ultimatelist.append(key) #adds these reformatted names to ultimatelist
# Out:
# Reformatted names:
# - - -
# Glasgow, Michael
# Moste, Lea
# Glasgow, Michael
# Billings, Alexandra
# Kanclerz, Jacob
# Wilson, Gary
# Smith, Lindsey
# Moste, Lea
# Glasgow, Michael
# Boven, Jacquelyn
# Forbes, Kevin
# Glasgow, Michael
# Glasgow, Michael
# Glasgow, Michael
# Glasgow, Michael
# Edwards, Marc
# Glasgow, Michael
# Glasgow, Michael
# Smith, Lindsey
# Edwards, Marc
# Guyette, Curt
# Crooks, Jennifer
# Edwards, Marc
# Edwards, Marc
# Guyette, Curt
# Edwards, Marc
# Smith, Lindsey
# Glasgow, Michael
# Glasgow, Michael
# Glasgow, Michael
# Edwards, Marc
# Edwards, Marc
# Guyette, Curt
# Guyette, Curt
# Fonger, Ronald
# Shekter, Jean
# Billings, Alexandra
# Billings, Alexandra
# Klaver, Christopher
# Fonger, Ronald
# Fonger, Ronald
# Fonger, Ronald
# Fonger, Ronald
# Guyette, Curt
# Fonger, Ronald
# Fonger, Ronald
# Fonger, Ronald
# Fonger, Ronald
# Fonger, Ronald
# Lorenz, Jason
# Carmody, Stephen
# Carmody, Stephen
# Fonger, Ronald
# Woodson, Arthur
# Fonger, Ronald
# Fonger, Ronald
# Fonger, Ronald
# Fonger, Ronald
# Fonger, Ronald
# Fonger, Ronald
# Lorenz, Jason
# Kanclerz, Jacob
# Michigan, Progress
# Fonger, Ronald
# Lorenz, Jason
# Lorenz, Jason
# Carmody, Stephen
# Edwards, Marc
# Edwards, Marc
# Guyette, Curt
# Lorenz, Jason
# Fonger, Ronald
# Fonger, Ronald
# Fonger, Ronald
# Kanclerz, Jacob
# Fonger, Ronald
# Wilson, Gary
# Emerson, Danielle
# Emerson, Danielle
# Emerson, Danielle
# Wittrock, Angela
# Smith, Lindsey
# Wittrock, Angela
# Emerson, Danielle
# Wittrock, Angela
# Hill, Bryan
# Amin, Sameen
# Henderson, Natasha
# Henderson, Natasha
# Edwards, Marc
# Edwards, Marc

# %%
roughlist2 = []
roughlist2.extend(lastcommafirstdude)
roughlist2.extend(firstlast1)
#roughlist2 = sum of names found to be in [First Last] and [Last, First]

roughlistd = list(dict.fromkeys(roughlist))
roughlist2d = list(dict.fromkeys(roughlist2))

duplicates = []
weedouts = []
def whatdiff(a, b):
    for i in a:
        if i in b:
            #print(i + " is in borth")
            duplicates.append(i)
    for i in a:
        if i not in b:
            #print(i + " was weeded out")
            weedouts.append(i)
            
msg = len(roughlist) - (len(roughlist2))
if msg > 0:
    n = str(len(roughlist))
    h = str(len(ultimatelist))
    print("out of " + n + " initial items, " + h + " are in ultimatelist.")
    print("")
    whatdiff(roughlistd,roughlist2d)
    print(str(weedouts) + " were weeded out.")
elif msg == 0:
    print ("No items were weeded out.")
elif msg < 0:
    print ("duplicates present: " + str(duplicates))
# Out:
# out of 421 initial items, 417 are in ultimatelist.
#
# ['DTMB Facilities', 'do-not-reply@detroitnews.com', 'WurfelB@michigan.gov', 'GOV Newsroom', 'Marc Edwards edwa'] were weeded out.

# %%
print("ULTIMATE LIST of SENDER NAMES in [Last, First]:")
print("- - -")
ultimateliststr = '\n'.join(ultimatelist)
print(ultimateliststr)
# final list :o)
# Out:
# ULTIMATE LIST of SENDER NAMES in [Last, First]:
# - - -
# Rosenthal, Adam
# Rosenthal, Adam
# Rosenthal, Adam
# Rosenthal, Adam
# Rosenthal, Adam
# Shekter Smith, Liane
# Prysby, Mike
# Cook, Pat
# Rosenthal, Adam
# Wurfel, Brad
# Shekter Smith, Liane
# Kaffer, Nancy
# Wurfel, Sara
# Wurfel, Brad
# Livengood, Chad
# Wurfel, Brad
# Busch, Stephen
# Devereaux, Tracy Jo
# Wurfel, Brad
# Wurfel, Brad
# Wyant, Dan
# Wurfel, Brad
# Murray, David
# Kaffer, Nancy
# Kaffer, Nancy
# Wurfel, Brad
# Macaluso, Nora
# Wurfel, Brad
# Waurfel, Brad
# Murray, David
# Crooks, Jennifer
# Prysby, Mike
# Benzie, Richard
# Busch, Stephen
# Prysby, Mike
# Wurfel, Brad
# Rennaker, Joanne
# Benzie, Richard
# Devereaux, Tracy Jo
# Benzie, Richard
# Rosenthal, Adam
# Benzie, Richard
# Ostrander, Debbie
# Rosenthal, Adam
# Benzie, Richard
# Rosenthal, Adam
# Bennett, Charles
# Brewster, Simone
# Rosenthal, Adam
# Shekter Smith, Liane
# Wurfel, Brad
# Busch, Stephen
# Tommasulo, Karen
# Rosenthal, Adam
# Prysby, Mike
# Busch, Stephen
# Fonger, Ronald
# Fonger, Ronald
# Fonger, Ronald
# Fonger, Ronald
# Guyette, Curt
# Fonger, Ronald
# Fonger, Ronald
# Fonger, Ronald
# Fonger, Ronald
# Fonger, Ronald
# Lorenz, Jason
# Carmody, Stephen
# Carmody, Stephen
# Fonger, Ronald
# Woodson, Arthur
# Fonger, Ronald
# Fonger, Ronald
# Fonger, Ronald
# Fonger, Ronald
# Fonger, Ronald
# Fonger, Ronald
# Lorenz, Jason
# Kanclerz, Jacob
# Michigan, Progress
# Fonger, Ronald
# Lorenz, Jason
# Lorenz, Jason
# Carmody, Stephen
# Edwards, Marc
# Edwards, Marc
# Guyette, Curt
# Lorenz, Jason
# Fonger, Ronald
# Fonger, Ronald
# Fonger, Ronald
# Kanclerz, Jacob
# Fonger, Ronald
# Wilson, Gary
# Emerson, Danielle
# Emerson, Danielle
# Emerson, Danielle
# Wittrock, Angela
# Smith, Lindsey
# Wittrock, Angela
# Emerson, Danielle
# Wittrock, Angela
# Hill, Bryan
# Amin, Sameen
# Henderson, Natasha
# Henderson, Natasha
# Edwards, Marc
# Edwards, Marc

# %%
ultimatelist_senders = list(dict.fromkeys(ultimatelist))

print(str(len(ultimatelist_senders)) + " unique senders found:")
print("")
print(ultimatelist_senders)
# Out:
# 81 unique senders found:
#
# ['Shoven, Heather', 'Dykema, Linda D.', 'Brewster, Simone', 'Whrfel, Brad', 'Byrne, Randall', 'Wurfel, Sara', 'Sygo, Jim', 'Crooks, Jennifer', 'Wyant, Dan', 'Murray, David', 'Anderson, Paula', 'Rosenthal, Adam', 'Boven, Jacquelyn', 'Cook, Pat', 'Eisner, Jennifer', 'Krisztian, George', 'Lasher, Geralyn', 'Benzie, Richard', 'Glasgow, Michael', 'Buhs, Caleb', 'Emerson, Danielle', 'Moste, Lea', 'Damato, Nicholas', 'Macaluso, Nora', 'Livengood, Chad', 'Guyette, Curt', 'Deltoral, Miguel', 'Kanclerz, Jacob', 'Holton, Jennifer', 'Klaver, Christopher', 'Brown, Jessica', 'Fortln, Denise', 'Feuerstein, Heather', 'Forbes, Kevin', 'Lorenz, Jason', 'Ostrander, Debbie', 'Michigan, Progress', 'Rosenthal, Adam HECY', 'Minicuci, Angela', 'Smith, Lindsey', 'Shaler, Karen', 'Saxton, Thomas', 'Busch, Stephen', 'Egan, Paul', 'Peeler, Nancy', 'Woodson, Arthur', 'Waurfel, Brad', 'Henderson, Natasha', 'Edwards, Marc', 'Muchmore, Dennis', 'Carmody, Stephen', 'Hill, Bryan', 'Prysby, Mike', 'Devereaux, Tracy Jo', 'Billings, Alexandra', 'Warfel, Brad', 'Wurfel, Brad', 'Wheaton, Bob', 'Hyde, Tinka', 'Poy, Thomas', 'Rennaker, Joanne', 'Ockert, Katherine', 'Fonger, Ronald', 'Amin, Sameen', 'Fortin, Denise', 'Miller, Mark', 'Grijalva, Nancy', 'Thelen, Mary Beth', 'Kaffer, Nancy', 'Tommasulo, Karen', 'Porter, Andrea', 'Workman, Wayne', 'Pratt, Jeff', 'Bennett, Charles', 'Pallone, Maggie', 'Wittrock, Angela', 'Shekter, Jean', 'Wilson, Gary', 'Shekter Smith, Liane', 'Dalebout, Rick', 'Shekter Smith, Llane']
