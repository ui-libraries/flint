# %%
from urllib import request

# %%
filenames_path = "filenames-subset.txt"
s3_root = "https://flint-text.s3.amazonaws.com/"
text_sample = ''

with open(filenames_path) as fp:
    lines = [line.rstrip('\n') for line in fp]

# %%
for line in lines:       
    url = s3_root + line
    response = request.urlopen(url)
    raw_text = response.read().decode('utf8')
    text_sample += raw_text

# %%
print(text_sample)
# Out:
#
#
#
#
#
#
# WV 00:00ZL 966L/81/6 _ESSNF 1002/€Z/0L  |WV 00:00:Z) €LOZ/IB _588& 0L0Z/9/Z)
#
# WV 00:00:Z) L66L/S/8 _s_(ttﬁ 666L/9L/F  |WV 00:00:ZL 00Z/I6 _sittur S00ZVEIZ
#
# WV 00:00Z) 886L/62/9 _s_<.=.§ 886L/SZ/E  |WV 00:00:ZL 066L/L/L _s_<88§ 1961/8/8
# _sittﬁ €L02/5Z  |WV 00:00:ZL ELOZ/OE/LL SIA|WV 00:00ZL €L0Z/BLIZ
#
# -_-sio:.ur 96861/L/L1 --_
#
# v I~ oxw | 0 omv | av | Ny ]| v
#
#
#
# _ 33ssT
#
# - JassT -
# - J3ssT -—
#
#
#
#
#
#
#
#
# 2157
#
# _Bc | Bb | B | Bf | BG | BH | B |BI| BK | BL | BM |
#
# BB
# II 1““995 HMMII||I|I “I
#
# . I - 'l'III"'
#
#
#
#
#
#
#
#
# Obtain three quotes whenever reasonably practicable
#
# Post bids online to the extent practicable
#
# Please escalate any questions to DTMB Procurement before executing a buy
#
# DTMB Procurement will assist any agency upon request to address supply chain
#
# issues (e.g. working with a national supplier to ensure a high volume supply of
#
# water fillers are available)
#
# o DTMB-Financial Services is not responsible for issuing emergency purchase
# orders on behalf of agencies with the exception of information technology related
# goods and services
#
# o Maintain documentation supporting all transactions. Establish internal protocols
#
# {o support this such as a single spreadsheet to track agency-wide transactions.
#
# Report your agency's axpansas to the SEOC Finance team via your SEQC
#
# representative.
#
# Q000
#
# Quaestions, concerns, or comments should be directed to:
#
# Primary Contact:
#
# Rebecca Cook, Commodities Division Director
# Cookré@michigan.qov
#
# Cell: 517-830-4015
#
# Secondary Contact:
#
# Jeff Brownlee, Chief Procurement Officer
# brownleej@michigan.gov
#
# Cell: 517-830-3472
#
# Sincerely,
#
# Jeff Brownlee
# Chief Procurement Officer
# State of Michigan
#
#
#
#
#
#
#
#
# MICHIGAN DEPARTMENT OF ENVIRONMENTAL QUALITY
# DRINKING WATER LABORATORY
#
# i USEPA Region V Drinking Water Cert. No. MIO0003
# EH‘I P.O. Box 30270
# : L.ansing, Ml 48809
# --.i TEL: (517) 335-8184 Sample Number
#
#
#
# FAX: (617) 335-8562 LF88957
#
# Official Laboratory Report
#
# Report To: MIKE GLASGOW
# 4500 N DORT HWY
# FLINT MI 48505
#
# System Name/Owner: CITY OF FLINT WSSN/Pool ID: 2310
#
# Collection Address: 3901 CHEROKEE AVE,FLINT Source: Single Family Dwelling
# Collected By: BARBARA COX Site Code:
#
# Township/Well#/Section: ] Collector: Private Citizen
#
# County: Genesee Date Collected: 10/19/2015 08:30
# Sample Point: KITCHEN . Date Received: 10/26/2015 15:42
# Water System: Other Purpose. Other
#
# ST RICIEIN S FIVTHED I s B s . RBEG h!L ATQRYH REQRNATIEN
#
#
#
# ‘Copper _ " 0/27/2096  0.05 EPA 200.8 7440-50-8
# Lead 0.003 10/27/2015  0.001 0.015 EPA200.8 7439-92-1
#
# The analyses performed by the MDEQ Drinking Water Laboratory were conducted using methods approved by the U .S, Environmental Prolection Agency in
# accordance with the Safe Drinking Water Act, 40 CFR parts 141-143, and other regulatory agencies as appropriate.
#
# Your local health department has detailed information about the quality of drinking water in your area. If you have
# concerns about the heaith risks related to the fost results of your sample, please contact the Environmental Health
# Section through the address and telephone number listed below:
# Genesee County Health Dept.
# 630 South Saginaw
# Flint, M| 485021540
# 810 257-3603
#
# : Chemical Absiract Service Registry Number mg/L : milligrams / Liter (ppm) Laboratory Contacts
# :  Maximum Contaminant Level ppm : paris per million Drinking Water Unit Mgr: Julia Pieper
#
# = Action Level MPN : Most Probable Number Systems Mgmt. Unit Mgr: George Krisztian
# : Reporfing Limit CFU : Colony Forming Unit
#
#
#
# By authority of PA 368 of 1978 as amended Work Order 61002957_09 Report Created on:  10/30/2015 8:55:43AM Page 1of 1
#
#
#
#
#
#
#
#
# MICHIGAN DEPARTMENT OF ENVIRONMENTAL QUALITY
# DRINKING WATER LABORATORY
#
# - USEPA Region V Drinking Water Cert. No. MI00003
# oy P.O. Box 30270
# e- " Lansing, Ml 48909
# et TEL: (517) 335-8184 Sample Number
#
#
#
# FAX: (517) 335-8562 LF44224
#
# Official Laboratory Report
#
# Report To: DOUGLAS ENVIRONMENTAL SERVICES
# 11082 BLAINE RD
# BRIGHTON MI 48114
#
# System Name/Owner.: WEST HAVENMH P WSSN/Pool ID: 40162
#
# Collection Address: WELL HOUSE,FLINT Source: TYPE |
#
# Collected By: JIM RICH Site Code:
#
# Township/Well#/Section: il Collector: Other
#
# County: Genesee Date Collected: 10/23/2014 08:50
# Sample Point: POE Date Received: 10/24/2014 08:25
# Water System: Treated Public Distribution System Purpose: Routine Monitoring
#
#
#
# Nitrite as N Not detected 10/24/2014 0.05 1 10-107-04-2-B 14797-65-0
#
# ." Fp Pl F B R
#
# Sulfate 23 10/24/2014 10 SM 4500 SO4E  14808-79-8
#
#
#
# The analyses performed by the MDEQ Drinking Water Laboratory were conducted using methods approved by the U.S. Environmental Protection Agency in
# accordance with the Safe Drinking Water Act, 40 CFR parts 141-143, and other regulatory agencies as appropriate.
#
# Your local health department has detailed information about the quality of drinking water in your area. If you have
# concerns about the health risks related to the test results of your sample, please contact the Environmental Health
# Section through the address and telephone number listed below:
#
# Genesee County Health Dept.
#
# 630 South Saginaw
#
# Flint, Ml 48502-1540
#
# 810 257-3603
#
# : Chemical Absfract Service Registry Number mg/L : milligrams / Liter (ppm) Laboratory Contacts
# : Maximum Contaminant Level ppm : parts per million Drinking Water Unit Mgr: Julia Pieper
#
# : Action Level MPN : Most Probable Number Systems Mgmt. Unit Mgr: George Krisztian
# : Reporting Limit CFU : Colony Forming Unit
#
#
#
# By authority of PA 368 of 1978 as amended Work Order 41003089_01 Report Created on: 10/27/2014 12:07:14PM Page 1 of 1
#
#
#
#
#
#
#
#
# o 0@ 0@ |sts6r
# o = 000z @000 |wseer
# o = 000000 @000 |ews6r
# o = 00000000 0@ [wser
# o = @@ 000000 [uwser
# o @@ 000000 |owser
# o = @00 0000000 [letser
# o @@ 000000 |seser
# o @@ 000000000 |esser
# o @@ 0000000 [|stser
#
# o @@ 00000 [osser
# o @@ 000000 [|ewer
# o @000 00000000 [|smer
# o @000 000000000 |user
# o @00 0000000 [|ser
# o = @00 00000 |seeer
# [ S, (715
#
# o @00 00000000 [|sser
# o @@ 0000000000 |aser
#
# 80861
# o @@ 0000 |oser
# o @@ 000000 [|svser
# o @@ 00000 |soser
# o @@ 000000 [voser
# o @@ 0000 [|eoser
# t__m
#
#
#
#
#
#
#
#
#
#
# 99¥ Jo €9 abed
#
# << 3LVAOLNVY>> [enuapyuo) [:awenN Auedwos]
#
# NOLLYISIDTT+HNNOATY+NOLLOT 13 +40+L SON+SNOIS+HITAANS/SMINRAIIAANS/¥EL 182 | €26 |
# UONYINOD+IHL+LOV.INOD/SMINAIIAANS/698.292] 225 |
# ALRIOHLNY+13O0d+ALNNOO+INAVMLION13A/STOV/SNOISSINNOD/SLNINLNIOJJdYAISAANS/ 925052 126 |
# SYIANIVYL+OILITHLV+JO+HIUVOLE+NVYOIHOIN/STOV/SNOISSINNOD/SLNINLNIODJdYAISAANS/ 12052 | 026 |
# SYUIANINVXI+MV T+10+QUVOE/STDVd/SNOISSINNOD/SLNIN.LNIODdYRAISAANS/-€666V2| 616 |
# TANVYd+ANOSIAQY+LNIWIDHOINT+MY T+SINHOS+SHIFWIN+LINIGYO+ITHOW+OML+STNVYN+ITAANS/SIASYITIU+SSITUJ/SMINMIAANS/- 820612 ﬁ
#
#
#
# ANV1IHOIS+SSTUd+UTAANS+SV+IANIS+OL+1INRUNMHVAVYS/STSYITIU+SSTUd/SMINATAANS/: 220872 L1LS |
# UONYIAOD+L1+IHL+LITW/OV14/SMINRAIIAANS/€9.872| 916 |
# Odr/ 2sessy LIVHLNOdAIIAANS/STDOVINIAOCD NYOIHOIW MMM/ dLLH| SIS |
# Odr/ 159605 100 9ZLINOWAIIAANS/SIDOVINI/AOCD NYOIHOIW MMM/ dLLH| ¥1S |
# WILSAS+HIVNOILLYONAI+SNVYOIHOIN+LNIANITU+OL+NV1d+STISANN+YIAANSAIAANS/ELS.S] €1S
# SLNIAISTU+NVYOIHOIN+YOI+STYWINY+IDIANTS+40+ISN+ONILOTLOUL+ST1IE+NVSILUVIS+SNOIS+ITAANS IOIN+AODIAANS/ELS.S] ZILS
# TIDNNOD+ANOSIAQY+HNTLSIN+TH.L+O1+SLNINLNIOddV+SINVIN+FITAANS-HIOIN+AOCD/SMINATAANS/ZLZZLE| LIS |
#
# SHOLVYONAI+NVOIHOIN+YO4+S
#
# NOLLYNTVAI+HJ3SYEHOUVISTU+ONLLNINT TdNI+TANSYIWHNVYSI LYV IS+SNOISHISAANSHADR+AOCD/SISVITI Y +SSIUd/SMINRISAANS /S 289¢E
# SNOLLYANIWWOOTU-+HINV+SONIANIH+SISYI1TU+IOUOA- ISV .L+ISNEV+HIIOIdOHINY+ONUA+NOILAINOSTUA/SMINATAANS/: L96.29€] 606 |
#
# W3 LSAS+NOILYON
#
# A3 +1VID3dS+SNVYOIHDIW+NI+STONVYHOHINIWNOD T +O L +IUOI-HIMSVY.L+SIWHOH +HIAANSIHORIHAOCD/SISYITIU+SSTUd/SMINRAISAANS/-SOV L9€
# QAVOE+ALRIOH.LNY-HINYL+IOVIOLSHINNOUDUIANN/STOV/SNOISSINNOD/SLNINLNIODdYAISAANS/:68821€ | 20S |
# NOILNTOS+IH.L+INV++SNI180Ud+SLION.LIA+40+LO0N+IHL+OIAIN/OOTE/SMINATAANS/ 879562 | 906 |
# NVOIHOIW+NI+S3ILIDHINO+ONRIOLSIN/O018/SMINRAITAANS/: LEEEBZ | SOS |
# SWILSAS+IONVUNSNI+LNIWAOTdNINN+dNOD+SUINIOM+ILVAdN+OL+STIIE+SNOISHIIAANS/SISVITIY+SSIUd/SMINAIAANS/-S0LL9C ﬁ
#
# QYVOE+LNIWLSIANI+LNITVL/STOV/SNOISSINNOD/SLNIWLNIOdJVRAIIAANS/:9.2.92] €0S
# UONYINOD+IHL+LIIN/STSYIT1IU+SSTU/SMINRIIAANS/PZLI9Z] 20S
# QIVOE+31VIOdN0D+00IN/STOVd/SNOISSINNOD/SINIW.LNIOddVAIAANS/:2985SZ] LOS |
# ALRIOHLNY+YNIYYNOLLNIANOO+ALNNOD+LNINSAId VI+ANVIO+IHL/STOV/SNOISSINNOD/SLNIWLNIOdJVRAIIAANS/:208052] 00S
# o0YUIO| 66
# SN+HTIONNOD+ONILYNIQUOOD+ISNOd ST +AONIOUIWT+ALINNNWODN I ZILID+NVYOIHDIN/SIOVd/SNOISSINWOD/S LNIWLNIODJdVYRISAANS /822052
# ALRIOH.LNY+39a1Ng+OVNIMOVIN/SIOVd/SNOISSINNOD/SLNIN.LNIOJdYRAISAANS/61L€0S2| 86V |
# NOISSINNOD+SIDUNOSTU+TVAUNLYN+NYOIHOIN/STOV/SNOISSINNOD/SLNIWLNIOdJVRAIIAANS/: LO00SZ| 267
# TIONNOD+ONINIVAL+SYIOIH40+TYNOLLOTUNOD/STOV/SNOISSINNOD/SLNINLNIODdYRAISAANS/-0686v2 | 96V |
# QYVOE+SNOLLOTUUOD+ALINNWNOD+NVYOIHOIN/STOV/SNOISSINNOD/SLNINLNIOJJdYRAISAANS/€286V2 | S6Y |
# 33.LLINWOO+NOINO+NVYOIHOIN/SIOVd/SNOISSINNOD/SLNIWLNIOdJVRAIIAANS/€186¥2Z] vBF
# TIONNOO+AYLSNANI+INIMHINY+IdVUD/STOVd/SNOISSINNOD/SINIWLNIOddVAIAANS/ 7 226vZ] €6 |
# SYISSVYANYO+ILV.1S+JO+HINVOH/STOVd/SNOISSINNOD/SINIW.LNIOdd Y AIIAANS/:08P6vZ] 26 |
# MWLH 00 —2020/€—222-2 8987 ORISAANS/AOD NVOIHOIW MMM//:d.LLH| L6 |
# 40ad'2 88va.y L1¥102 O3RAITAANS/SININNDOA/AOD NYOIHOIW MMM/ dLLH| 06 |
# €L0Z/SNOLLYWVY 100N d/SMINAIZAANS/:62009] 68F
# ZL0Z/SNOLLYINV100¥d/SMINRAISAANS/72009] 88 |
# | LOZ/SNOILLYINV100¥d/SMINRIIAANS/:€2009| 28V |
# SINNLLNOOMOVEINOD+SNVYOIHOIN++H+SAVS+YIAANS+ILV.LS+IHL+JdO+3 LV ISAIIAANS/E.S.S] 98F
# NOISSINNOD+SOLLNYNOYIV+NVYOIHOIN+3H.L+O1+03.LNIOddVIU+VYNNHIVAVIRIIAANS/:€.S.S| S8Y |
# ININLYIY1+3SNEV+IONVYLSENS+IAINOUd+++d 1TH+OL+T1IG+SNDIS+HITAANSIIOIR+AODRIIAANS/€LS.S] ¥8Y |
# NVYOIHOIN+NI+LNIWLSIANI+HTJINNILNOD+SIUNSNI+ONINNY1d
#
# +1300dN9+31V1iS+SNIHLONIULS+LNINIFUOV+STTIHONOLNY+ITTSAUHO+LVIS+UFAANSHIDR+AOD/SISVYI T U+SSTUd/SMINRTAANS/-S 1669
#
#
#
# << HlVd OLNVY >>
#
#
#
#
#
#
#
#
# o | € 1 ¢ | e | w | 1 |
# 1/21/2016 |  leed | O |  Copper [ 0  ]3508 CLOVERTREE LN | FUNT | 48532
# 1/21/2016 | lead | 3 | Copper [ 110 [2446CORUNNARD |  FUNT [ 48503 |
# 1/21/2016 | leed | 6 |  Copper | 0  [1430E HAMILTON AVE | FUNT | 48506
# 1/21/2016 |  leed | O | Copper [ 0 6932 YORKSHIRE DR | FUNT | 48505
# 1/21/2016 | lead | 0 | Copper [ 3%  [648HURONST |  FUNT | 48507 |
# 1/21/2016 | lead | 0 | Copper [ 0  [1913SEYMOUR |  FUNT | 48503 |
# 1/21/2016 |  leed | 10 |  Copper | 50 2746 BROWN STREET | FUNT | 48503
# 1/21/2016 | lead | 200 |  Copper [ 2130 [SISWMARENGO |  FUNT | 48505 |
# 1/21/2016 |  leed | O |  Copper | 8 4029 MILBOURNE AVE | FUNT | 48504
# 1/21/2006 | lead | 0 | Copper [ o f 00000000000 00O |
# 1/21/2016 |  leed | 2 |  Copper [ 100 2222 MONTEITH ST | FUNT | 48504
# 1/21/2016 | lead | 0 | Copper [ O  [J02ECOURTAPT601 |  FUNT [ 48503 |
# 1/21/2016 |  leed | O |  Copper | 80  |316 WEST BUNDY AVE | FUNT | 48505
# 1/21/2016 | lead | O | Copper [ O  [PMERSONRD |  FUNT | 48505 |
# 1/21/2016 0 [ Copper | 130 |G4IWHOMEAVE |  FUNT | 48505
# 1/21/2016 5 | Copper | 90  |3OSMLKINGAVE |  FUNT | 48505
# 1/21/2016 2 | Copper | 0  [308THOMST 000200 |  FUNT | 48506
# 1/21/2016 0 [ Copper | O  |eslaDUPONTST |  FUNT | 48505
# 1/21/2016 0 [ Copper | O  |426EGRACELAWN |  FUNT | 48505
# 1/21/2016 4 | Copper | 70  380SLORRANE |  FUNT | 48506
# 1/21/2016 0 [ Copper | 0  [3uu7THOMST 00000000 |  FUNT | 48506
# 1/21/2016 0 | Copper | 0  [1018 HAMMOND AVE | FUNT | 48503
# 1/21/2016 1 [ Copper | 8  [3809BEECAWOOD |  FUNT | 48506
# 1/21/2016 | 0 | Copper | O [2324LAPEERRD #308 | FUNT | 48503
# 1/21/2016 5 | Copper | 270  |7I6WPIERSONRD |  FUNT | 48505
# 1/21/2016 0 [ Copper | O  |ei3stevensst 00000000000 | 00| |
# 1/21/2016 1 [ Copper | 240  |3710BRANCHRD |  FUNT | 48506
# 1/21/2016 7 |  Copper | 0 [2302 OKLAHOMA AVE | FUNT | 48506
# 1/21/2016 1 |  Copper | 8 (714 MACDONALD AVENUE | FUNT | 48507
# 1/21/2016 0 [ Copper | O  [3413BRENTAVE 0|  FUNT | 48506 |
# 1/21/2016 4 [ Copper | 250  |1925OWENST |  FUNT | 48503
# 1/21/2016 3 |  Copper | 280  [320 WSECONDAVE | FUNT ]
# 1/21/2016 5 |  Copper | 410  [1614 ARLINGTON AVE | FUNT | 48506
# 1/21/2016 0 | Copper | 0 [3618 PINGREEAVE | FUNT | 48503
# 1/21/2016 0 [ Copper | 150  J1918uoypst 0000 |  FUNT | 48504
# 1/21/2016 0 | Copper | 0 [625WEST HOLBROOK AVE | FUNT | 48505
# 1/21/2016 |0 |  Copper | 130 (1002 COPEMAN BLVD | FUNT | 48504
# 1/21/2016 0 [ Copper | O  |3726CRAIGDR |  FUNT | 48506
# 1/21/2016 0 [ Copper | O  |3711BRANCHRD |  FUNT | 48506
# 1/21/2016 2 |  Copper | 70  [1118SOUTHLAWN AVE | FUNT | 48507
# 1/21/2016 0 [ Copper | O  |1114WPIERSONRD |  FUNT | 48505
# 1/21/2016 o0 [ copper | 0  JsoosmiAamilN 00000000000 |  FUNT | 48504 |
#
# LG01982
# LG01983
# LG01984
# LG01985
# LG01986
# LG01987
# LG01988
# LG01989
# LG01990
# LG01991
# LG01992
# LG01993
# LG01994
# LG01995
# LG01996
# LG01997
# LG01998
# LG01999
# LG02000
# LG02001
# 2037 LG02002
# LG02003
# LG02004
# LG02005
# LG02006
# LG02007
# LG02008
# LG02009
# LG02010
# LG02011
# LG02012
# LG02013
# LG02014
# LG02015
# LG02016
# LG02017
# LG02018
# LG02019
# LG02020
# LG02021
# 2057 LG02022
# LG02023
#
# 017
#
#
#
#
#
# 027
#
# EIEIE[RIREIRIRIEISISISIRIRERIRIRIES
#
#
#
#
#
# 047
#
#
#
# Kl BB EHEH R BREEEE
#
#
#
# g
#
#
#
#
#
#
#
#
# e
# o 4.1‘&-11 =0y
# T
#
# lrx
#
# 3t
#
#
#
# .
#
# S
#
# i3
#
# L
#
#
#
#
#
# G T 20 SaSiealt el O ML
#
#
#
#
#
#
# Case Study #2: Presentation of a School’s Experience
# Ron English, Deputy General Counsel, Seattle Public Schools
#
# The second case study was presented by Ron English and focused on the experiences of the
# Seattle School District. The district has faced many challenges related to lead in drinking water in the
# past year, but was finally able to adopt a new policy on December 1, 2004.
#
# Background
#
# The Seattle School District is an inner-city district (42 percent of 47,000 students qualify for free
# or reduced lunch) with an aging stock of buildings. They purchase their water from Seattle Public
# Utilities. In 1991-1992 lead testing was conducted. About 25 percent of drinking water fountains were
# found to exceed 20 ppb. The bubblers at these fountains were replaced, but not the plumbing. A flushing
# program was instituted, but was not consistently applied. Recommendations that the plumbing at 4
# schools in the district be replaced were not implemented due to levy failures. The results of the testing
# were never made public and no action was taken from 1992 until 2003.
#
# In 2003, parents became aware of and publicized problems with iron in school water. Testing
# also exposed elevated lead levels. High lead fevels were found in a kindergarten classroom. One student
# was reported to have become ill after she was introduced to the classroom and improved afier she lefi;
# however, she was never tested for lead.
#
# Action
#
# The school district immediately provided bottled water for all schools over 7 years old (60
# schools) and hired a consuitant to create a comprehensive testing program for the district. Testing took
# place at all schools (included testing for lead, cadmium, iron, copper, E. Coli, color and turbidity). A
# decision was made that water was not to be consumed from any fountain/tap until testing showed that it
# was safe. Water from drinking fountains in hallways, classrooms, and sinks were tested after an 18-hour
# period of stagnation following flushing. Testing indicated lead over 20 ppb in 25% of locations.
#
# The testing program revealed lead levels rebound tfo their original levels in just 2-3 hours, so a
# drinking fountain must be used frequently throughout the day to keep levels down. Replacing the bubbler
# didn’t completely solve the problem because the 250-mL test samples also drew water from 7-feet of
# piping behind the fountain. In the summer of 2004 the plumbing was replaced at the 4 schools where this
# had been recommended in the 1990's.
#
# Most of the kitchens in the district use pre-packaged foods and therefore use minimal water.
# These taps were not considered high priority. Age-appropriate warning signs have been posted in all
# restrooms warning children not to drink the water from these taps.
#
# Letters were sent to every parent in the district.
# Iron Removal
#
# Iron was the original problem that brought water quality issues to light in 2003. Now, the iron
# standard for Seattle Public Schools is almost as strict as that used for public water systems. One option
# for removing high iron is to install filters. It was determined that drinking water filters work at about half
# the rated capacity. They tend to clog after a few hundred gallons and therefore cannot be relied upon for
# the entire year.
#
# 5
#
#
#
#
#
#
#
#
# unconscionable.
#
# Our state government is responsible for ensuring that safe, clean water is accessible to all—a
# seemingly basic task in the Great Lakes state. In Flint, they failed.
#
# As a result, families will be dealing with the effects of poisoned water for years to come.
#
# While there is no way to make up for the bad decisions and cover-up comments made to date, it
# is imperative that the state view the water pollution crisis in Flint as requiring both short-term and
# long-term solutions. Flint families will be dealing with the repercussions of poisoned water for
# years to come.
#
# Governor Snyder and his administration must certainly repair critical water infrastructure, but they
# must also help heal the ailing residents of the city, and restore the public trust that has
# understandably eroded. What happened in Flint could happen in countless other cities in
# Michigan relying on aging water infrastructure.
#
# It is time for Governor Snyder to take full responsibility for the Flint water crisis while also
# taking pro-active steps to ensure that this kind of public health crisis never happens again in Flint
# or anywhere else In the state of Michigan. This will mean much-needed investment and policy
# changes at both the state and federal levels, which will necessitate leadership and determination.
#
# As a Michigan LCV member, you understand that whom we elect matters. You and your fellow
# members also understand that, once elected, our decision-makers must be held accountable for
# their actions—for protecting our air and land and ensuring that every Michigan citizen has access
# to clean, safe drinking water.
#
# In this time of true water crisis, our work is more important than ever as we keep a close eye on
# the words, decisions and actions coming out of Lansing. Your support makes this possible. Thank
# you.
#
# Sincerely yours,
# Lisa Wozniak
#
# Executive Director, Michigan LCV
#
# Update Your Profile
# To Unsubscribe Click Here
#
# 3029 Miller Road
# Ann Arbor, MI 48103
# 734-222-9650
#
# nonprofit software
#
#
#
#
#
#
#
#
#
#
# 14 __—_mmm
# Service Address Service City POD Number | inMcf | Fixed COG |
# T050 Dearing 275565 —%7 | 5%
#
# | 16 [Mic hlgan State Police
#
# | 17 [Michigan State Police Northville 42145 Seven Mile mm_ 2589657 | 92 | 530 |
#
#
#
# | 18 |Michigan State Police
# | 19 |Michigan State Police
#
#
#
# 3401Cooperst  |Jackson (598827 0000000 | 153 | 530
# 14350 W 10 Mile Rd OakPark (3538102 | 1334 | 530
# | 20 | Michigan State Police 405NEuclidAve ~ [BayCty (2051356 | 09 | 530
# EI Michigan State Police 9755MainSt  [lapeer 1794112 2= 22222 | 141 | 530
#
# 22|DMBlotterM113 0202022 [101EHillsdale St lansing  [2303784 ~ =~========Z2020202= | 746 | 530 |
# 23 [DMB MSP Post 1 M203 7119NCanalRd  [Dimondale 1884437 | 214 | 530
# 24 |DMB Record Center 3400NGrandAve  |lansing 3557607 222 | 73 | 530
# 25 |DMB Record Center 3400NGrandAve#A ~ |lansing 2343172 = | 1563 | 530
# | 26 |DMB Rickle SOBM214 7707RickeSt  |lansing 3556629 | 2632 | 530
# | 27 [State of Michigan DTMB 301ElouisGlickHwy  |Jackson (275358 | 366 | 530
# 28 |DMB Saginaw SOB M410 411 E Genesee Ave Saginaw  |2898012 0002020202 | 1467 | 530 |
# 29 | DMB Flint SOB M407 125EUmion  |Flint 122173 2 200002 | 4142 | 530
# | 30 |Dept of Milt Vet Affairs Joint Force 3323 N Martin Luther King Jr B lansing (35522 | 4891 | 555
# 31 |DMVA Grand Ledge 10700EFatonHwy  [Grandledge 3558335 | 2558 | 555
# | 32 | Mmilitary Affairs Mk Rediness Cent 3423 N Martin Luther King Bivd#2  [lansing 3557574 | 1207 | 555 |
# | 33 |Dept of Milt Vet Affairs Joint Force 3411 N Martin Luther King Jr Bl lansing (355222 | 1091 | 555
# 34|DMVAFlint 0020202000000 [110llewisst  |Fint 81160 = | 685 | 55
# 35 |DMVA Financial Services 4850CooperSt  |Jackson (3553694 22020202022 | 1989 | 555
# 36 |DMVA Grand Ledge 10600EFatonHwy  |Grandledge 3558341 | 267 | 555
# "37 |DMVA Midland Armory 2300AirportRd  [Midland 707447 = | 1375 | 555
# 38 |DMVA Shiawassee Armory 675 W Corunna Ave Corunna (3557883 | 1058 | 555
# 39|DMVAPontiac 0 [233NJohnsonSt  |Pontiac  |2935%s 22 | 616 | 55
# | 40 [DMVA Camp Grayling 3423 N Martin LutherKingBlvd#2  |lansing  [3966607 | 572 | 555
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I!EEE R
#
# E R R el e e SR S A e S
# ™ ™ ™ m|m ™ ™ ™
#
#
#
#
#
#
#
#
# From: Wurfel, Brad (DEQ)
#
# To: Busch, Stephen (DEQ):; Benzie, Richard (DEQ); Shekter Smith, Liane (DEQ)
# Cc: Pallone, Maggie (DEQ): Wyant, Dan (DEQ)
#
# Subject: FW: here"s the interim report
#
# Date: Thursday, July 09, 2015 4:53:41 PM
#
# From: Lindsey Smith [mailto:Imsmi@umich.edu]
# Sent: Thursday, July 09, 2015 4:48 PM
#
# To: Wurfel, Brad (DEQ)
#
# Subject: here's the interim report
#
# attp://www.aclumich.org/sites/de¢
# Lindsey Smith
#
# West Michigan Reporter
#
# Michigan Radio
#
# Office (616) 551-0717
# ichi 1
#
# LI
#
# erReport0624
#
#
#
#
#
#
#
#
# L |
# PROMISE ZONES ( ) Allows additional promise zones and
# modifies their administration.
#
# Immediate Effect; Earlier concurred in House H-1 substitute 38-0
#
# I
#
# |
#
# STATE EDUCATION TAX ( ) Modifies distribution of state
# education tax.
# Immediate Effect
#
# |
#
# ]
# PASSED
#
# FLINT WATER SUPPLEMENTAL ( ) Provides for distribution of
# certain appropriated revenue from the state General Fund to assist in
# the Flint water crisis.
#
# 38-0; Immediate Effect; Earlier adopted amendment; Earlier advanced
#
# to Third Reading; Earlier adopted committee substitute S-1
# L
#
#
#
#
#
#
#
#
# DTMB Real Estate Division
# Active Lease Report as of March 1, 2014 - Lease by Department
#
# ] A | a4 ] A | A~ | A& | a | 0 A
#
# Chlcago IL 60607 N/A -Branch |Branch Office
# Office
# 370
#
# Benton Harbor 49022 N/A - Branch |Branch Office
# Office
# 371
#
# Coldwater 49036 N/A - Branch |Branch Office
# Office
# 372
#
# Kalamazoo 49005 N/A -Branch |Branch Office
# o
# 373
# 49224 N/A -Branch |Branch Office
# o |
# 374
#
# Cassopolls 49031 N/A -Branch |Branch Office
# Office
# 375
#
# Cheboygan N/A -Branch |Branch Office
# o | T
# 376
#
# Waest 48322 N/A -Branch |Branch Office
# T e
# 377
#
# Midiand 48840 N/A -Branch |Branch Office
# o |
# 378
#
# Office
#
# 379
#
# Grayling 49738 N/A -Branch |Branch Office
# o |
#
# ! o ‘ - - = “
# Office
#
# 5 o ' o - - one k
# Office
#
#
#
# 183 of 336
#
#
#
#
#
#
#
#
# and any attachments may not be forwarded or reproduced without express
# permission from Gongwer News Service.
#
#
#
#
#
#
#
#
# 1 A~ { s 00| c 1 o | e | ¢ | e [ H |
# 463]  5/17/2013|CONSUMERS ENERGY COMPANY . 2013ses3) 00000000 | 0000000000 00| elia] 00|
# 464  5/17/2013| CONSUMERS ENERGY COMPANY 2013643y 0000000 | 00000000000 00| 38070 @00
# 465|  5/13/2013|STARBASENC 02000000 l0sa3.a3AlPeNA | 000000000 | 00000000000 | 0| 1490724
# 466]  5/13/2013|STARBASENC 02020020000 josa3u3eATL | 000000000000 00000000000 00| 1934502]
# 467]  5/10/2013|STARBASENC = jost013o8e | 00000000000 00000000000 | | 5223789] @
# 468]  5/17/2013| MEDLINE TRANSCRIPTION LLC 1300 0 20} 000000000 | 480000
# 469]  5/17/2013|CHARTER COUNTY OF WAYNE 13-0008 1 &4y 00
# 470]  5/17/2013|SCHNEIDERMAN AND SHERMAN, PC 130007 0 000\ 00000000 | 601814 @
# 471]  5/17/2013/CITIMORTGAGEINC 13004 | | | | 473823
# 472]  5/20/2013|CONSUMERS ENERGY COMPANY . 2013se43f 00000000 | 00000000000 00| swmEl 00
# 473  5/20/2013| CONSUMERS ENERGY COMPANY . 2013se43) 0000000 | 0000000000 00| 79225 @000
# 474]  5/20/2013| CONSUMERS ENERGY COMPANY . 2013se43) 0000000 | 00000000000 | e1608) |
# 475  5/20/2013| CONSUMERS ENERGY COMPANY . 2013se43) 0000000 | 000000000 0| 0811 @
# 476]  5/20/2013| CONSUMERS ENERGY COMPANY . 2013se43) 0000000 | 00000000000 | 43303 |
# 477]  5/20/2013| CONSUMERS ENERGY COMPANY . 2013se43) 0000 0 | 0000000000 | 103214
# 478]  5/20/2013| CONSUMERS ENERGY COMPANY . 2013se43) 000000 | 0000000 00| 16 00
# 479]  5/21/2013|SAMUEL HAGLUND 4/024f0sp3 | 0000000000 | 00000 00| 485 |
# 480]  5/21/2013|JOSEPH M MEREDITH 434272 | 000000 | 0000 00| 15848 @
# 481]  5/22/2013|RICOHUsAINC |  201ses3y 00| 000000 00| @ 2493 @0
# 482]  5/20/2013|DTEENERGYCO  jo4/osospoii3 | 0 | ] 750720 00
# 483]  5/20/2013|DTEENERGYCO = jo4pospops | ] so1e
# 484]  5/20/2013|DTEENERGYCO = jo4/usjospis | 0 p 0 | | 102070 00
# 485  5/20/2013|DTEENERGYCO ~~~~ [4jo3s/83 | 000000000 0000000000 00| ey
# 486]  5/20/2013|DTEENERGYCO ~~ jo400sp0p3 | 0 | | 1697) 000
# 487]  5/20/2013|DTEENERGYCO  jo430sp33 | 000000000 00000000000 | | 97024
# 488]  5/20/2013| CONSUMERS ENERGY COMPANY 410050903 | 2000000\ 00000 00| 7334
# 489]  5/20/2013| CONSUMERS ENERGY COMPANY o41005/09/3 | 00000000\ 00000 00| 964
# 490]  5/20/2013| CONSUMERS ENERGY COMPANY 0410050943 | 0000000 | 00000 | 379595/ @
# 491]  5/20/2013| CONSUMERS ENERGY COMPANY 0410050913 | 000000000 00000000 | 168451
# 492]  5/20/2013|CONSUMERS ENERGY COMPANY o4100s/0943 | 00000000 | 000 00| 31356 |
# 493]  5/20/2013| CONSUMERS ENERGY COMPANY 410050943 | 0000000\ 0000 00| 13%40
# 494]  5/20/2013| CONSUMERS ENERGY COMPANY 04040533 | 0000000 | 000000 | 18365 |
# 495|  5/20/2013|DTEENERGYCO  |o400sf/9/13 | 000 0000000000 | 184565
# 496]  5/20/2013|LEAK PETROLEUM EQUIPMENT INC 0 wewyy 0O\ 0000 00| a3 @0
# 497]  5/20/2013|LEAK PETROLEUM EQUIPMENT INC Fcs7_ 0y | e& @0
# 498]  5/3/2013|RICOHUsAINC | = 103987153y 000 0000000 000 0004
# 499]  5/21/2013/TROISAMISCoRP 00000000000 | 0 s3] 000000} 00000 000 078
# 500  5/21/2013|LAKECITYREDIMX |  8ess | 00| | @ 16
# 501]  5/23/2013]MAY SIMPSON & STROTE PC vooe8®1 | 00000000\ 000000000 | 7821400, @
# 502]  5/3/2013 TOWNSHIP OF GRAYLING B30 | 000000000\ 00000000 | 102100
# 503]  5/15/2013BIO SERV CORPORATION . seesy 000000000} 00000000 00| @08 @000
# 504]  5/21/2013[DU HADWAY KENDALL & ASSOCIATES INC . 6ae7] 00O 00O 1 s
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# HLNOW|WV 00:00-2l 0002/SL/Zl
#
# VANV 00-00-21L 6002/LE/L
#
# HLNOW|WV 00-00-2l 8002/LE/S
#
# WV 00:00-Z1 0002/L/01L
#
# WV 00:00-Z) 2.61/€2/9
#
# WV 00:00-ZL S002/L/9
#
#
#
#
#
#
#
#
#
#
#
#
# ® Need to support parents and programs to
# improve parenting skills
#
# @ Evidence-based parenting programs
#
#
#
# @ IncredibleYears (HCH AAP Grant)
# ® TripleP
# Everyday Parenting
#
# Adventuresin Parenting
# Home visiting programs
# Strengthening Families Framework
#
#
#
#
#
#
#
#
#
#
# need to avoid at all costs.
#
# Brian and Scott, can you tie in with Tom Summers and troubleshoot what is wrong? See below for a description of what
# we are seeing.
#
# Jason
#
#
#
# From: Summers, Thomas (DTMB)
#
# Sent: Wednesday, January 27, 2016 4:28:44 PM
#
# To: Stephens, Jason (DNR); Newman, Jeremy (DTMB); Raizada, Bhavna (DTMB); Simmons, Allen (DTMB); Chauhan,
# Pruthviraj (DTMB); Meshram, Vilas (DTMB); Anderson, Mark (DTMB); Avidi, Eswar (DTMB); Heym, Douglas (DNR);
# Asselin, Donovan (DNR); Heckman, Daniel (DNR); Singh, Ajay (DTMB); Prestel, Carl (DTMB)
#
# Subject: RE: MiFl QA not working?
#
# Jason, There is a problem with some of the feature tables. Scott Noldy and Brian Maki will have to work together to get
# them straightened out.
#
# Tom
#
# From: Stephens, Jason (DNR)
#
# Sent: Wednesday, January 27, 2016 4:16 PM
#
# To: Newman, Jeremy (DTMB); Raizada, Bhavna (DTMB); Simmons, Allen (DTMB); Chauhan, Pruthviraj (DTMB);
# Meshram, Vilas (DTMB); Anderson, Mark (DTMB); Avidi, Eswar (DTMB); Heym, Douglas (DNR); Asselin, Donovan (DNR);
# Heckman, Daniel (DNR); Summers, Thomas (DTMB); Singh, Ajay (DTMB); Prestel, Carl (DTMB)
#
# Subject: MiFI QA not working?
#
# Importance: High
#
# Donovan and | just tried to verify the MiFl QA environment (http://iqa.dnr.state.mi.us/MiFi/# ) is ready for testing, and
# neither of us have data in the map. | got the impression from this morning’s scrum that we should be able to being
# preparations for UAT next week. Did | miss something?
#
#
#
#
#
#
#
#
#
#
# From: Thelen, Mary Beth (DEQ)
#
# Sent: Monday, October 12, 2015 12:53 PM
# To: Sygo, Jim (DEQ);Krisztian, George (DEQ)
# Subject: FW: Lead Numbers Discussion with DEQ Team - Preliminary and Deliberative: Not
#
# subject to FOIA (Meeting Notice)
#
# FYL.
#
# From: Benzie, Richard (DEQ)
#
# Sent: Monday, October 12, 2015 12:53 PM
#
# To: Thelen, Mary Beth (DEQ)
#
# Subject: Automatic reply: Lead Numbers Discussion with DEQ Team - Preliminary and Deliberative: Not subject to FOIA
# (Meeting Notice)
#
# 1 will be away from the office and unable to respond to your message until Wednesday,
# October 28th. If you need assistance before then, please contact Tracy Jo Devereaux
# b gov) and she will direct you to someone who can be of assistance.
#
#
#
# Richard Benzie, P.E., Chief
#
# Field Operations Section
#
# Office of Drinking Water & Municipal Assistance, MDEQ
# 517-284-6512
#
#
#
#
#
#
#
#
# From: Granish, Philip (MDOC)
#
# To: MDOC-FLINT-WATER
# Subject: FW: Gongwer News Service Michigan Media Clips
# Date: Monday, February 22, 2016 10:46:38 AM
#
# From: gongwerreports@gongwer.com [mailto:gongwerreports@gongwer.com]
# Sent: Wednesday, January 27, 2016 8:42 AM
#
# To: Michigan_State_Employees_clips@gongwer.com
#
# Subject: Gongwer News Service Michigan Media Clips
#
# ]
#
# ( ,1/27/2016)
# ( . 1/27/2016)
# ( ,
# 1/27/2016)
# (
# ,1/27/2016)
# ( ,
# 1/27/2016)
# ( ;
# 1/27/2016)
# ( . 1/27/2016)
# ( , 1/27/2016)
#
# ( ,1/27/2016)
#
#
#
#
#
#
#
#
#
#
#
#
# 7741 |pkohlerll@gmail.com
#
# 7742 |glenlondon2002@yahoo.com
# 7743 |petrovichc@grps.org
# | 7743
#
# | 7744 |angela.cartwright@detroitk12.org
# | 7745 |jjefftartag@aol.com
#
# | 7746 |speanut24@gmail.com
# | 7747 |ddwhitney@wowway.com
# | 7748 |jmaser@fenton.k12.mi.us
# | 7749 |phuny1101@aol.com
#
# | 7750 |htand3k@aol.com
#
# | 7751 |Cora.A.Gregory@gmail.com
#
# 7752 |scarter@sisd.cc
#
# | 7753 |herbekr@hillmanschools.com
# | 7754 |Dickens254@comcast.net
#
# | 7755 [tinalaub@comcast.net
#
# | 7756 |w8bp@charter.net
#
# 7757 |etsweiler@gmail.com
# 7758 |missmatt@comcast.net
# 7759 |becky.kramer@emich.edu
#
# 7760 |schultzpg@yahoo.com
#
#
#
#
#
# Paula  |Basic =~ 200202002020 |https
# Cndy ~ |Basic = |https
# Cynthia  |Basik =~~~ 0020 |https
# Angela Basic 000 |htips
# Basic 000 |htips
# Basc 0000 [|htips
# Basic 000 |htips
# Joyee ~ |Basic 02000 |https
# Patricia  |Basik =~ 0202020202 |https
# Kathleen ~ |Basic =~~~ |https
# Corajean ~ |Basik =~~~ 00202 |https
# Shawn  |Basic =~ 020202000 |https
# Randy  |Basic = |https
# lauie  |Basik == 0002020020020 |https
# Kenneth ~~ |Basik =~~~ 020 |https
# John  |Basik 000 |https
# John  |Basie 0000 |https
# Tamatha  |Basic =~ 020200 |https
# Becky ~ |Basic = 0202020200200 |https
# Pauline ~ |Basik =~~~ =002 |https
#
# 7761 |jhkh6@aol.com Kristy ~ |Basic = |https
#
# 7762 |bonnieak5@aol.com
# J-wilma@att.net
#
# 7763 |j.wilma@
# sgarvin@beavertonruralschools.com
#
# 7764 |sgarvin@b Ischool
#
# 7765 |Marc.lott@myeagles.org
#
# 6 @ I
#
# 7766 |lynnrogers@charter.net
#
# 7767 |glen.modell@gmail.com
#
# 7768 |bethany@deschaine.net
#
# 7769 |yorkbrown@sbcglobal.net
# jennysu yahoo.com
#
# 7770 e43@yahoo
# mavanest@delta.edu
#
# 7771 @delta.ed
#
# 7772 |gardenpeace2@gmail.com
# mnyland@ameritech.net
#
# 7773 yland@ itech
# captaincaddie@yahoo.com
#
# 7774 incaddie@yah
# mscott@atheronschools.org
#
# 7775 @ath hool
#
# 7776 |jbdenny1990@gmail.com
#
# 7777 |ryoung@wecskids.net
# 7778 |kt0Olbps@birmingham.k12.mi.us
#
# | 7779 |rtolliver1930@att.net
#
# | 7780 |tvanabel@nmu.edu
#
# | 7781 |kjarrad@wpcschools.org
#
# | 7782 |kschroeder@cvs.k12.mi.us
#
# | 7783 |whfisher@yahoo.com
#
# | 7784 |muskteacher12@hotmail.com
#
# | 7785 |lelenbaas@springlakeschools.org
#
#
#
#
#
# Bonnie  |Basik =000 |https
# Wilma  |Basik =~ 002000 |https
# Shery ~~ |Basic =~ 00202000 |https
# Marc  |Basic 0202020202000 |https
# ynn  |Basie 000000 |https
# Glen ~~ |Basic =000 |https
# Bethany ~ |Basic =~ 0202020 |https
# York Basic 000 |htips
# Jennifer ~ |Basik = 0202002000 |https
# Mary ~ |Basic 0020000 |https
# Audrey ~ |Basik =~ 0200020020 |https
# Melissa ~ [Basic ~~~~  |https
# Stephen ~ |Basik =~ 02002020200 |https
# Mark ~ |Basik =~ 020020020 |https
# Jeffery Basic 000 |htips
#
# honda Basic 00 |htips
# Km  |Basic 00000 |https
# Rosle ~ |Basik =~~~ = |https
# Tracy  |Basic 00000 |https
# Karen  |Basik =~ 002000 |https
# Kelly ~ |Basie ~~~~ |https
# William  |Basik =~ 000202020020 |https
# Roger ~~ |Basic 000 |https
# Linda  [Basic [https
#
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //werw.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //www.michigan
# //werw.michigan
# //www.michigan
#
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
# gov/orsmiaccount
#
#
#
#
#
#
#
#
#
#
#
#
# e
#
#
#
#
#
#
#
#
# Laboratory Director
#
# Michigan Department of Environmental Quality
# Desk ph (5617) 284-6719
#
# Cell ph (517) 204-0381
#
#
#
#
#
#
#
#
# o | € 1 ¢ | e | w | 1 |
# /202016 |  leed | O |  Copper [ 190 602 KENSINGTON AVE | FUNT | 48505
# 1/20/2016 | lead | 0 | Copper [ 100 [3S06MACKINRD |  FUNT | 48504 |
# /202016 |  leed | 1 |  Copper | 0  [3202 SALISHANCIR | FUNT | 48506
# 1/20/2016 | lead | 2 | Copper [ O  [SIOFERIDGEWAY |  FUNT | 48505 |
# /202016 |  leed | 2 |  Copper | 0 |535 WEST GRACELAWN AVE | FUNT | 48505
# /202016 |  leed | O |  Copper [ 0  [1214F CARPENTARRD | FUNT | 48505
# /202016 |  leed | O |  Copper [ 0 3243 WLYNDONAVE | FUNT | 48504
# /202016 |  leed | O |  Copper | 160  |3745 DOLPHAINE LN | FUNT | 48506
# 1/20/2016 | lead | 0 | Copper [ O  [2010NDORTHWY |  FUNT [ 48506 |
# 1/20/2016 9 | Copper | 280 |171BNEBRASKAAVE |  FUNT | 48506
# 1/20/2016 4 | Copper | 8  |1508WELCHBIYD |  FUNT | 48504
# 1/20/2016 5 | Copper | O  |o07FRANKST 0000 |  FUNT | 48504
# 1/20/2016 49 | Copper | 0 [1109 REMINGTON AVE | FUNT | 48507
# 1/20/2016 0 [ Copper | O  [2706PLAINFIELD |  FUNT | 48506
# 1/20/2016 3 |  Copper | 100  [3201 SALISHAN CIRCLE | FUNT | 48506
# 1/20/2016 0 | Copper | 0  [1218F GRACELAWNAVE | FUNT ]
# 1/20/2016 4 | Copper | O  |o02ERDGEAVE |  FUNT | 48505 |
# 1/20/2016 0 [ Copper | 230  |2022NORTHST |  FUNT | 48505
# 1/20/2016 0 |  Copper | 50 [1820 CHELSEA CIRCLE | FUNT | 48503
# 1/20/2016 0 [ Copper | O  |386ORRST |  FUNT | 48532
# 1/20/2016 2 | Copper | O  |702CRAWFORD 0202 |  FUNT | 48507
# 1/20/2016 0 [ Copper | O  |3207BRANCHRD |  FUNT | 48506
# 1/20/2016 0 | Copper | O [3462 EVERGREEN PKWY | FUNT | 48503
# 1/20/2016 2 |  Copper | 110  [2460 THOMAS STREET | FUNT | 48504
# 1/20/2016 10 | Copper | 0 [1606 SUNCREST DR | FUNT | 48504
# 1/20/2016 0 | Copper | O [4807 CANTERBURY LANE | FUNT | 48504
# 1/20/2016 1 [ Copper | 60  JaSWELCHBIWD 02020202 00 00 |  FUNT | 48503
# 1/20/2016 0 [ Copper | O  J4924WMARENGO =02 |  FUNT | 48505
# 1/20/2016 24 | Copper | 70  |701WHAMWTON 0020202 |  FUNT | 48504
# 1/20/2016 4 | Copper | 220 [731ERUTH 0000000000 |  FUNT | 48505 |
# 1/20/2016 0 | Copper | 0 [3710 BRUNSWICKAVE | FUNT | 48507
# 1/20/2016 2 |  Copper | 0 [3019 COMANCHE AVE | FUNT | 48507
# 1/20/2016 0 [ Copper | 8  [|725COLUMBIADR |  FUNT | 48503
# 1/20/2016 106 |  Copper | 0 [1014 BLANCHARD AVE | FUNT | 48503
# 1/20/2016 4 | Copper | O  |3706ESTERST |  FUNT | 48505
# 1/20/2016 1 [ Copper | 60  Jas13MwtoN 0 00000000 |  FUNT | 48507
# 1/20/2016 9 | Copper | 60  1039FDMHAVE 000000 | = FUNT | 48507 |
# 1/20/2016 3 |  Copper | 70  [3629 FENWICK CIRCLE | FUNT | 48503
# 1/20/2016 0 | Copper | 0 [3201COLORADO AVE | FUNT | 48506
# 1/20/2016 8 [ Copper | O  |701WHAMWTON 0000 |  FUNT | 48504
# 1/20/2016 0 |  Copper | 130  [6021 COVERED WAGONS TR | FUNT | 48532
# 1/20/2016 0 [ copper | 0  [s91asusaNsT 000 |  FUNT | 48505 |
#
#
#
# 3
#
# =1 =11
#
# LGO0890
# LG00891
# LG00892
# LGO0893
# LG00894
# LGO0895
# LGO0896
# LG00897
# LG00898
# LGO0899
# LGO0S00
# LG00901
# LG00902
# LGO0903
# LG00904
# LGO0905
# LGO0906
# LGO0907
# LG00908
# LGO0909
# LG00910
# LG00911
# LG00912
# LG00913
# LG00914
# LG00915
# LG00916
# LG00917
# LG00918
# LG00919
# LG00920
# LG00921
# LG00922
# LG00923
# LG00924
# LG00925
# LG00926
#
# 09
#
#
#
# i
#
# 107
#
#
#
#
#
# |
# i
#
# | [B12IE(ElalRlE = s B R R R A AR A A B BB R B S A A AR
#
# 17
#
#
#
# 127
#
#
#
#
#
#
#
#
#
#
# 4014 Fenton Rd.
# 4022 Fenton Rd.
#
# 101 Fenton Rd.
#
# 103 Fenton Rd.
#
# 106 Fenton Rd.
#
# 109 Fenton Rd.
#
# 118 Fenton Rd.
#
# 126 Fenton Rd.
#
# 201 Fenton Rd.
#
# 202 Fenton Rd.
#
# 202 Fenton Rd.
#
# 205 Fenton Rd.
#
# 211 Fenton Rd.
#
# 211 Fenton Rd.
#
# 214 Fenton Rd.
#
# 218 Fenton Rd.
# 4301 Fenton Rd.
# 4302 Fenton Rd.
# 43086 Fenton Rd.
# 4306 Fenton Rd.
# 4317 Fenton Rd.
# 4317 Fenton Rd.
# 4401 Fenton Rd.
# 4402 Fenton Rd.
# 4402 Fenton Rd.
# 4405 Fenton Rd.
# 4409 Fenton Rd.
# 4412 Fenton Rd.
# 4412 Fenton Rd.
# 4413 Fenton Rd.
# 4417 Fenton Rd.
# 4420 Fenton Rd.
# 4420 Fenton Rd.
# 4501 Fenton Rd.
# 4501 Fenton Rd.
# 4506 Fenton Rd.
# 4517 Fenton Rd.
# 4517 Fenton Rd.
# 4522 Fenton Rd.
# 4801 Fenton Rd.
# 4801 Fenton Rd.
# 4806 Fenton Rd.
# 48086 Fenton Rd.
# 4809 Fenton Rd.
# 4617 Fenton Rd.
# 4617 Fenton Rd.
# 4619 Fenton Rd.
# 4619 Fenton Rd.
#
# go
# F
# |
# = | v
#
# 1
#
# NN
# o |
# P
# FF
#
# <TI0
# o|o|o
# P e
#
# OMjO
# o |
# [
# F
#
# 1
#
# R R B[R
# el ]
#
# g
# [
# F
#
# g
# P P
#
# A
# 4014FentonRd.
# 4022 FentonRd.
# 4101 FentonRd.
# 4103 FentonRd.
# 4106 FentonRd.
# 4109 FentonRd.
# 4118FentonRd.
# 4126 FentonRd.
# 4201 FentonRd.
# 4202 FentonRd.
# 4202 FentonRd.
# 4205FentonRd.
# 4211 FentonRd.
# 4211 FentonRd.
# 4214FentonRd.
# 4218 FentonRd.
# 4301 FentonRd.
# 4302FentonRd.
# 4306 FentonRd.
# 4306 FentonRd.
# 4317 FentonRd.
# 17830[4317 FentonRd.
# 17831/4401 FentonRd.
# 17832{4402 FentonRd.
# 17833{4402 FentonRd.
# 178344405 FentonRd.
# 17835{4400 FentonRd.
# 178364412 FentonRd.
# 4412FentonRd.
# 4413FentonRd.
# 4417 FentonRd.
# 4420 FentonRd.
# 4420 FentonRd.
# 4501 FentonRd.
# 4501 FentonRd.
# 4506 FentonRd.
# 4517 FentonRd.
# 4517 FentonRd.
# 4522 FentonRd.
# 4601 FentonRd.
# 4601 FentonRd.
# 4606 FentonRd.
# 4606 FentonRd.
# 4609 FentonRd.
# 4617 FentonRd.
# 4617 FentonRd.
# 4619 FentonRd.
# 4619 FentonRd.
#
# M
# g
# ~
#
# h
# vl
#
# I M
# D
#
# §
# [
# F
#
# P e
#
# [
# F
#
#
#
#
#
#
#
#
#
#
# To best protect public health, Snyder and MDHHS advise residents to continue using water
# filters. Free filters are available for current MDHHS clients at the 125 E. Union St. or 4809 Clio
# Road MDHHS office locations. For residents who are not currently enrolled in MDHHS
# assistance programs, free filters are available at the Genesee County Community Action
# Resource Department offices at 2727 Lippincott and 601 North Saginaw in Flint. Staff will be
# onsite at all four locations from 9 a.m. to 4 p.m., Monday through Friday, to distribute filters and
# assist residents who have questions about proper installation.
#
# At the Lippincott location only, extended hours will be offered this weekend, including until 7
# p.m. on Thursday and Friday and from 10 a.m. to 2 p.m. on Saturday.
#
# Other good practices for residents concerned about lead include tuming on the cold water tap
# and running the water until it's as cold as it will go. Additionally, only use cold water for cooking,
# drinking and especially mixing baby formula.
#
# The state today also released the first results from its free lead screening program in schools
# and homes. Of 37 total samples taken at 13 buildings, four samples spread over three buildings
# exceeded the federal action level of 15 parts per billion.
#
# However, this sampling provided only a first screen, and the state is committing to further testing
# as well as plumbing inspections of these schools. Until testing is complete, schools are advised
# to continue using bottled water and filtration as a precaution to protect children.
#
# In addition, free testing is still available for any other Flint school, including daycares and Head
# Starts. Free testing is also available for any Flint resident.
#
# Additional information, including more detailed lead screening results, is available at
# www.michigan.gov/flintwater.
#
# HHt
#
#
#
#
#
#
#
#
# (404] = 44004|Michigan eLibrary (Mel.org)
# (405] = 44004|Michigan eLibrary (MeL.org)
# | 44004|Michigan eLibrary (MeL.org)
#
# 1 407] = 44004|Michigan eLibrary (Mel.org)
# (408] @ 44004|Michigan eLibrary (MeL.org)
# 4089] = 44004|Michigan eLibrary (MeL.org)
#
# 1 410] = 44004|Michigan eLibrary (MeL.org)
# (411] 44004 |Michigan eLibrary (MeL.org)
# | 44004|Michigan eLibrary (MeL.org)
# (413] = 44004|Michigan eLibrary (MeL.org)
# (414] @ 44004|Michigan eLibrary (Mel.org)
#
# 44816 |Engler Holds Firm on Veto Promise; "Ballot proposal is bad public policy, plain and simple"
#
# 44816 |Engler Holds Firm on Veto Promise; "Ballot proposal is bad public policy, plain and simple"
#
# 45074 |Governor Engler Signs Bill Creating Film Advisory Commission: Commission will help put
# Michigan in the movies
# 45074 |Governor Engler Signs Bill Creating Film Advisory Commission: Commission will help put
#
# | 45158|GM Pontiac Plant Eamns Governor's Recognition
# (420] = 45158|GM Pontiac Plant Eams Governor's Recognition
#
# Governor Congratulates Grubbs on Intention of President Bush to Nominate Him as U.S.
#
# Marshal
#
# Governor Congratulates Grubbs on Intention of President Bush to Nominate Him as U.S.
#
# Marshal
#
# Governor Engler Signs General Fund Budget Bills; Keeps Budget Balanced, Protects Critical
#
# Programs and Strengthens Commitment to Public Schools
#
# Governor Engler Signs General Fund Budget Bills; Keeps Budget Balanced, Protects Critical
#
# Programs and Strengthens Commitment to Public Schools
#
# Governor Praises Michigan's U.S. Senators for Vote that Helps States Maintain Medicaid and
#
# Social Service Programs
#
# Governor Praises Michigan's U.S. Senators for Vote that Helps States Maintain Medicaid and
#
# Social Service Programs
#
# 45676 |Governor Names Newest Clean Corporate Citizen: TRW Automotive is 46th facility to eam
#
# 427 environmental honor
#
# M 45676 |Governor Names Newest Clean Corporate Citizen: TRW Automotive is 46th facility to eamn
#
# environmental honor
#
# M 45773|Governor Commends Teachers and Administrators for their Support of Michigan's School Aid
# Budget: Michigan Leads the Nation in Funding Public Schools
#
# m 45773|Governor Commends Teachers and Administrators for their Support of Michigan's School Aid
# Budget: Michigan Leads the Nation in Funding Public Schools
#
# '(431] = 46351|Cascade Engineering Recognized as Clean Corporate Citizen
#
# 1432] = 46351|Cascade Engineering Recognized as Clean Corporate Citizen
#
# M 46480|Statement from Governor John Engler in response to local governments' call for veto override
# of state revenue sharing
#
# m 46480|Statement from Governor John Engler in response to local governments' call for veto override
# of state revenue sharing
#
# ﬁ 46497 |Michigan Prosecutors Honor Governor Engler; Governor urges law enforcement to fight drug
# leqgalization
#
# M 46497 |Michigan Prosecutors Honor Governor Engler; Governor urges law enforcement to fight drug
# leqgalization
# 1437] = 46550|Happy Birthday Michigan.govl More services, more traffic and more awards
#
# '(438] = 46550|Happy Birthday Michigan.govl More services, more traffic and more awards
# (439] = 46553|Engler Appoints Clark to Head Department of Consumer and Industry Services
#
# M
# F
# -
#
#
#
#
#
#
#
#
#
#
# MICHIGAN DEPARTMENT OF ENVIRONMENTAL QUALITY
#
# DRINKING WATER LABORATORY
# o USEPA Region V Drinking Water Cert. No. MI00003
# s P.O. Box 30270
# ¥ Lansing, MI 48909
#
# TEL: (517) 335-8184 Sample Number
# FAX: (517) 335-8562 | F91946
#
# Report To: STEVE BUSCH
# 525 WALLEGAN
# LANSING MI 48909
#
#
#
# Official Laboratory Report
#
# System Name/Owner.: WSSN/Pool ID:
#
# Collection Address: CENTRAL KITCHEN,FLINT Source: Other
#
# Collected By: TJD/GLK Site Code: CA3
# Township/Well#/Section: il Collector: MDEQ DWRPD Staff
# County: Genesee Date Collected: 11/14/2015 09:21
# Sample Point: KCO005 Date Received: 11/16/2015 07:16
# Water System: Other Purpose: Other
#
#
#
# Lead Not detected 11/17/2015 0.001 0 01 5 EPA 200. 8 7439-92-1
#
# The analyses performed by the MDEQ Drinking Water Laboratory were conducted using methods approved by the U .S. Environmental Protection Agency in
# accordance with the Safe Drinking Water Act, 40 CFR parts 141-143, and other regulatory agencies as appropriate.
#
# Your local health department has detailed information about the quality of drinking water in your area. If you have
# concerns about the health risks related to the test resuits of your sample, please contact the Environmental Health
# Section through the address and telephone number listed below:
#
# Genesee County Health Dept.
#
# 630 South Saginaw
#
# Flint, Ml 48502-1540
#
# 810 257-3603
#
# : Chemical Abstract Service Registry Number mg/L. : milligrams / Liter (ppm) Laboratory Contacts
# : Maximum Contaminant Level ppm : parts per million Drinking Water Unit Mgr: Julia Pieper
#
# : Action Level MPN : Most Probable Number Systems Mgmt. Unit Mgr: George Krisztian
# : Reporting Limit CFU : Colony Forming Unit
#
#
#
# By authority of PA 368 of 1978 as amended Work Order 61101669_03 Report Created on: 12/10/2015 2:59:04PM Page 1 of 1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# DWO002 HALLWAY P2
# DWO002 HALLWAY FO1
# DWO001 HALLWAY N
# DWO001 HALLWAY P2
# DWO001 HALLWAY FO1
#
# CF023 RM #19
# CF023 RM #19
# CFO12 RM #9
# CFO12 RM #9
# CFO08 RM#4
# CFO08 RM#4
# CFO07 RM#3
# CFO14 ROOM #10
# CFO14- ROOM #10
# CF014-ROOM #10
# CF026 ROOM #14
#
# lead  [0.001 [DWOO2HAUWAY  |F02 |
# lead  [0.002  [CF012 RM #9
#
# lead _ [0.004
# lead  [0.001 [DWOOIHAUWAY  |F02 |
#
# lead  [0.014  |CFO18 RM#15
# lead  [0.002  |CFO18 RM#15
#
# PB__ |lead 0010  [CFO17 RM#15
# 63|LF88812 |PB  [lead 0014 CFOIRM#1S  [P2
#
# lead 0002  |CFO12 RM #9
# lead 0005  |CFO18 RM#15
# lead 0002  |CFO18 RM#15
# 64|LF88813 [PB  Jlead 0002  |CFO17 RM#15
#
# lead (0004
#
# lead (0000
#
# lead (0040
#
# lead (0006
#
# lead (0004
#
# lead (0027
#
# L lead (0007
#
# | 80|LF88820 |PB  |lead  0.004
#
# JiiE Sle
# PP m
# mmm
#
# F F
# LLLLLLLLLLLL
#
# 88811
#
# 46|1F88795 |PB  [lead 0015 |DWOO2HALUWAY  [P1
# nmﬁz-m 0.006
#
# | 81]1F88830 [PB  |lead 0003  |CFO14-ROOM #10
# | 82[1F88831 [PB  |lead 0036  |CF026 ROOM #14
# 83[LF88832 [PB  |lead 0030  |CF026 ROOM #14
# | 84]iF88833 |PB  Jlead  0.017
#
# [43|1F88792 [PB  |lead 0.003
#
# 44|1F88793 [PB  |lead 10001  |CF023 RM #19
# 45[1F88794 [PB |lead 0.000
#
# 65[iFas814 [PB  |lead 0002  |CFO17 RM#15
# | 66|LF88815 [PB  |lead  0.017
#
# 70|LF88819 [PB  lead 0013  |CFOOS RM#4
#
# | 71[LF88820 [PB |lead 0.006
#
# 72|1F88821 [PB  lead 0001  |CFOOS RMi4
#
# | 73|LF88822 [PB  |lead  0.000
#
#
#
#
#
#
#
#
#
#
# e The Governor’s Office has asked each agency to perform their own searches on their
# email/repositories for all information pertaining to the Flint Water crisis.
#
# ¢ While the agencies may approach DTMB for assistance, we are under a tight timeframe and
# can’t possibly assist every agency and every employee.
#
# o If the agency asks for DTMB assistance and you have internal resources available to assist
# (i.e. Client Specialist), please provide that assistance.
#
# o if the agency needs assistance from OA {i.e. due to a large quantity of email/documents
# or a large group of people) please forward that request to Jodi Simon. Also, please let
# the agency know that requests will be prioritized by the Governor’s Office and we will
# provide feedback on availability as soon as possible (so if DTMB cannot assist, it will still
# leave time for the agency to perform the searches).
#
# » The Governor’s Office will provide the keyword search terms today to the Agencies.
#
# o The designated agency coordinators for this project will identify which employees from
#
# their agency will be the Custodians.
#
# Please call me with any questions.
# Thank you
#
# Tiziana Galeazzi
#
# General Manager for Attorney General, Civil Rights, Executive Office of the Governor, Talent and
# Economic Development
#
# State of Michigan, Department of Technology, Management and Budget
#
# Cell: (517) 749-9496 Office: (517) 241-3310
#
#
#
#
#
#
#
#
# Flint Residential Testing Report - results collected through February 13, 2016
#
# P~
# o~
# LN
# L+ )
#
# LG12180
# LG12191
# LG12198
# LG02710
# LG01909
# LG06958
# LG10207
# LG10746
# LG01178
# LGO8593
# LG07788
# LG06476
# LG04026
# LG02667
# LG07870
# LG07872
# LG10468
# LG06185
# LG02072
# LG01691
# LG11850
# LG02753
# LG04203
# LG06840
# LG01450
# LG06052
# LG07737
# LG07581
# LG06192
# LG06908
# LG09945
# LG09969
# LF87019
# LG06913
# LG02458
# LG02124
# LG09242
# LG04184
# LGO5550
# LG03163
# LG01749
# LG08748
#
# 2/11/201
# 2/11/201
# 2/11/201
# 1/23/201
# 1/21/201
# ...
# 3.8.2 Surveillance of water SUPPHES .....coceeeeieriiceeeiececenee 25
# 3.8.3 Occupational health and safety agencies .........cccecrvecncrennnn.e. 25
# 3.9 Standard-setting and certification bodies.......cccceerirnreenrinccnenceiceecnne 26
# 3.10 Training Providers ........ccoc oottt 27
# 4 Water Safety PLAIS.....cocssccacescssssssssassessessnssassnsasenssssensasesssssensasssssssssassssessaassens 31
# 4.1 Background............ieieeeeecerereere e tssare s s e sass e e aneesnsans 31
# 4.2 Key principles Of WSPs...... oo 32
# 4.3 Assembling a WSPLeam ...t encsnsecenecssceaas 33
# 4.4 Describing the water SYSEEM.......cccceecrararancreraneesnrasneasameessasensessonsasnsens 33
# 4.4.1 Functions of water networks inside buildings ..........ccceeeeennneenee. 34
# 4.4.2 Usages and water-use patterns......co.ceoveeeemrsvenescenssescensanssnescanenns 34
#
# 4.4.3 Understanding and documenting the design of the
# WALET SYSLEIM . eerecaeeceaecreascmeesnsearesscnsasamsesssasasesssnsasamsenssasassasnns 36
# 4.5 Identifying hazards and hazardous evVents.....c..ccccccreeeeecrcereeesscneecraresnenes 42
#
# iv Water safety in buildings
#
#
#
#
#
#
#
#
# TERMINATED
# 3176
#
# Standard; 90 days /
# Standard; 90 days /
# Standard; 90 days /
# Standard; 90 days /
# Standard; 90 days /
#
# Standard; 120 day /
# Standard; 120 day /
# Standard; 120 day /
#
# Standard; 90 days /
# Standard; 90 days /
# Standard; 90 days /
# Standard; 90 days /
# Standard; 90 days /
#
# Standard; 120 day /
# Standard; 120 day /
# Standard; 120 day /
#
# 60 Days; Standard Cancellation /
#
# Five year; 60 days /
# Five year; 60 days /
#
# 5 years; 80 days /
# 5 years; 60 days /
# 5 years; 80 days /
# 5 years; 80 days /
# 5 years; 80 days /
# 5 years; 80 days /
# 5 years; 80 days /
# 5 years; 80 days /
# 5 years; 80 days /
# 5 years; 80 days /
#
# 5 year; 80 day /
# 5 year; 80 day /
# 5 year; 80 day /
# 5 year; 80 day /
# 5 year; 80 day /
# 5 year; 60 day /
#
# Notice; 30 days /
# Notice; 30 days /
# Notice; 30 days /
# Notice; 30 days /
# Notice; 30 days /
# Notice; 30 days /
# Notice; 30 days /
# Notice; 30 days /
# Notice; 30 days /
# Notice; 30 days /
#
# ELECTRICITY /
# ELECTRICITY /
# OTHER/
# OTHER/
#
# GROSS (FULL SERVICE) /
# GROSS (FULL SERVICE) /
# GROSS (FULL SERVICE) /
# GROSS (FULL SERVICE) /
# GROSS (FULL SERVICE) /
#
# GROSS (FULL SERVICE) /
# GROSS (FULL SERVICE) /
# GROSS (FULL SERVICE) /
#
# GROSS (FULL SERVICE) /
# GROSS (FULL SERVICE) /
# GROSS (FULL SERVICE) /
# GROSS (FULL SERVICE) /
# GROSS (FULL SERVICE) /
#
# GROSS (FULL SERVICE) /
# GROSS (FULL SERVICE) /
# GROSS (FULL SERVICE) /
#
# HVAC /
# ELECTRICITY /
# WATER /
# JANITORIAL /
# INT/EXT MAINT /
# LANDSCAPING /
# SNOW REMOVAL /
# PARKING /
# FLUORESCENT /
# RUBBISH REMOVAL /
# N/A [/
#
#
#
#
#
#
#
#
#
#
# €0LT
# VIN
#
# ¢0LT
# VIN
#
# T10LT
# VIN
#
# 00LT
#
# II.! ‘Bpig UOSEI O} Y0BQ POAO “ededs “dwie] l.
# . da | o8
#
#
#
# VIN
#
#
#
#
#
#
#
#
# Nina Cole
#
# Sales Representative
#
# VWR International/Michigan
# Education and Medical Research
#
# nina_cole@vwr.com
# Cell {858) 210-1543
# Fax {610} 728-2517
#
# http://www.vwr.com
# Please excuse any typing errors this is sent from my iPhone.
# OnJan 17, 2016, at 10:30 PM, Shane, Kirby (DEQ) <SHANEK@ michigan.gov> wrote:
#
# Hi Nina - Not sure if you're working tomorrow, Monday, 01/18/16. Can you give me a quick update on how
#
# many bottles (cases), VWR part number 71001-158, you can get us and by when. | may be looking at a few hundred
# cases. We are working under a Federal Emergency. | am not in the office tomorrow but will be checking emails and may
# try to give you a call. What's the best number to get you at.
#
# thank you,
# Kirby
#
# From: Nina_Cole@vwr.com <Nina_Cole@vwr.com>
#
# Sent: Friday, January 15, 2016 8:47 AM
#
# To: Sambiagio, Melissa (DTMB)
#
# Cc: Andy_Garrison@vwr.com; Johnson, Dora (DEQ); Lewis McMillan@VWR.COM; Pieper, Julia (DEQ); Shane, Kirby (DEQ); Smith,
# Carol (DEQ)
#
# Subject: RE: C&G bottles 71001-158
#
# Hi Melissa,
#
# Yes we can send samples from this lot, however, it will slow down production for the order if speed is still the top
# priority. Please let me know what we need to do to help.
#
# Bryan Walker from C&G is checking to see if we sent samples previously as these were on our previous proposed bottle
# list as well. | am waiting to hear back from him and | will let you know what he says.
#
# Best,
# Nina
#
# Nina Cole
#
# Sales Representative
#
# VWR International/Michigan
# Education and Medical Research
# nina cole@vwr.com
#
# Cell (858) 210-1543
#
# Fax (610) 728-2517
#
# nHp./Awww. ywr.com
#
#
#
#
#
#
#
#
# said, where the lead actually bonds to the iron sediment. While the particulates of lead/iron are small, they’re very
# highly concentrated with lead-—up to 85% lead.
#
# Miguel was wondering if Flint is feeding Phosphates. Flint must have Optimal Corrosion Control Treatment-—is it
# Phosphates? Or is it pH/Alkalinity Adiustment? The reason he asks, is because systems using the pH/Alkalinity
# adjustment have problems with [ead levels in the 100's or higher--and they have problems with random lead particulate
# matter in the distribution system. Miguel said that we all know that flushing regularly helps reduce the lead
# concentrations, but not immediately. The City can’t just flush in advance of taking the compliance samples, they have to
# flush the lines on a regular schedule.
#
# The problem with high lead issues, is that the water has so many different variables, that it's hard to pinpoint what is
# causing what problem where. From a public heailth perspective, can we assume that the high lead levels in Mrs. Walters’
# neighborhood are isolated to just her area? Or are they more widespread?
#
# Please feel free to contact Miguel directiy—312-886-5253; Deltoral.miguel@epa.gov.
#
# ilennifer
#
# From: Prysby, Mike (DEQ) [mailto:PRYSBYM®michigan.gov]
# Sent: Thursday, February 26, 2015 10:25 AM
#
# To: Crooks, Jennifer
# Cc: Busch, Stephen (DEQ); Rosenthal, Adam (DEQ)
# Subject: RE: HIGH LEAD: FLINT Water testing Results
#
# Jennifer,
#
# | recall Adam showing me a high lead/copper sample result {perhaps it was this one)....as part
# of the city’s routine lead-copper monitoring. if so, it was a stagnated sample as part of the
# sampling protocol. Adam mentioned that ali other samples were below the Al...and the city
# will not exceed the lead AL, | will confirm this. The city; however, needs to take further
# action to help address Ms. Walter’s concern. The type of plumbing needs to be identified and
# sample tap location within the premise plumbing. They should offer to re-sample for PB after
# flushing the tap to demonstrate that flushing the tap will reduce the lead concentration. The
# city also needs to provide other lead-reduction strategies to Mrs. Walters.
#
# Michael Prysby, P.E.
#
# District Engineer
#
# Office of Drinking Water and Municipal Assistance
# 517 290-8817
#
# From: Crooks, Jennifer [[naiio:crook: ifer@epa.aov
# Sent: Thursday, February 26, 2015 10 53 AM
#
# To: Busch, Stephen (DEQ); Prysby, Mike (DEQ)
#
# Cc: Poy, Thomas; Deltoral, Miguel
#
# Subject: HIGH LEAD: FLINT Water testing Results
#
#
#
# Hi, Steve and Mike. Thanks for talking with me yesterday, Steve, about the most recent TTHM resuiis. We'll iook forward
# to receiving them whenever vou get them back from the lab.
#
#
#
#
#
#
#
#
# ! A | 8 | c¢ | 00D 000000
# 181 [Cathoun  [231  [11336-2007-0121|Syear;60day |
# (182 |Calhoun ~ [231  |2329-2006-0085 |10 year; 30 day
#
# (183 |Calhoun ~ [231  |2329-2006-0085 |10 year; 30 day
#
# 184 |Calhoun ~ [231  |2329-2006-0085 |10 year; 30 day
#
# (185 |Calhoun ~ [431  [10362-2011-0233 |5 Years: 30 days
#
# 186 [Calhoun ~  [431  |10362-2011-0233 [5 Years: 30 days
#
# (187 |Calhoun ~ [431  [10362-2011-0233 |5 Years: 30 days
#
# 188 |Calhoun 431  |2524-2007-0032 |5 YEARS; 90 DAYS
#
# 189 |Calhoun 431  |2524-2007-0032 |5 YEARS; 90 DAYS
#
# 190 |Calhoun 431  |2524-2007-0032 |5 YEARS; 90 DAYS
#
# 191 |Cathoun 431  |2524-2007-0032 |5 YEARS; 90 DAYS
#
# 192 [Calhoun  |431  [2524-2007-0032 |5 YEARS; 90 DAYS
#
# 193 |Calhoun 431  |2524-2007-0032 |5 YEARS; 90 DAYS
#
# 194 |Calhoun 431  |2524-2007-0032 |5 YEARS; 90 DAYS
#
# 195 |Calhoun 431 [2524-2007-0032 |5 YEARS; 90 DAYS
#
# 196 |Calhoun 431  [2524-2009-0009 |Syear;90day
# 197 |Cathoun 431 [2524-2009-0009 |Syear;90day
# 198 |Cathoun 431  [2524-2009-0009 |Syear;90day
# 199 [Calhoun  [431  [2524-2009-0009 |Syear;90day |
# 200 |Calhoun 431  [2524-2009-0009 |Syear;90day
# 201 |Calhoun 431  [2524-2009-0009 |Syear;90day
# 202 |Calhoun 431  [2524-2009-0009 |Syear;90day
# 203 |Calhoun 431  [2524-2009-0009 |Syear;90day
# 204 |Calhoun 431  [2524-2009-0009 |Syear;90day
# 205 [Calhoun  [431  [2524-2009-0009 |Syear;90day |
# 206 |Calhoun 472 [11394-2008-0057|Syear;60day
# 207 |Calhoun 472 [11394-2008-0057|Syear;60day
# 208 |Cathoun 472 [11394-2008-0057|Syear;60day
# 209 |Cathoun 472 [11394-2008-0057|Syear;60day
# 210 |Cathoun 472 [11394-2008-0057|Syear:60day
# 211 [Calhoun  [472  [11394-2008-0057|Syear:60day |
# 212 |Cathoun 472 [11394-2008-0057|Syear:60day
# 213 |Cathoun 472 [11394-2008-0057|Syear:60day
# 214Cass 431  [10412-1996-1311|Syear;60day
# 215|Cass 431  [10412-1996-1311|Syear;60day
# 216|Cass 431  [10412-1996-1311|Syear;60day
# 217|Cass 431  [10412-1996-1311|Syear;60day
# 218fCass  [431  [10412-1996-1311|Syear;60day |
# 219Cass 431  [10412-1996-1311|Syear;60day
#
#
#
# 225 [Charlevoix __ [231  [11647-20120286(30Days |
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 6131 VG
# 00'000°02
# 0000801
# 0i¢
# 00'000'00¢
#
# swe}| OS3S
#
# |o1uU0D) o1yel |
#
# lojiel] JeumQy/iesulbug
# 08PIA UOI1ONJISU08Id
# uonezijiqon
#
#
#
#
#
#
#
#
#
#
# 1~ 1 & [ ¢ T o5 T ¥ T —F Tel w T 1T T 7
# i | |weeiecdeyAve oz |whwe wiade x| | [k
# 2076 10/6/2015___|Uippincot 1861 SPRINGFIELD as503 _ BecoAts  ewis x| | Jx
# 2077]10/6/2015 _|saginawst ____[1861 Springhield st 48503 lewss ecoas [ x
#
# ol | |mesawdiae
#
# 2079] = | = |1862Springfield St.
# 2080 @ | @ |1862Springfield St.
# 2081[10/6/2015 _|Lippincott 1863Hoser = = = [48503  segle =000 [tames = 00000 |x | 00kx 0f 000
# 2082l @200 @000 [1863S. AverillAve. 48503  fspencer =~ = = fprisaila 000000 fx | 000 @00 |x
# 2083) = [ 2 [1s68Gilmartinst. 48503  fphillips ~ [Renita 0000000 fx | 0000000 000 ]x 00
# 208f = [ 00 [1872Gilmartin 48503  fcalico fianet 0 fx | 000000 000 ]x
# 208s] = [  [1901Bayberrylane 48507  [Griggs =~ [Rosemary = 00 fx | 0000 Jx | @000
# 2086[10/7/2015  [saginawst. ~  [1901Begole =~ === Ja8so4  fwiliam === [Harvey = 00 fx | 000000 @ Jx
# 2087]10/9/2015 __ |Lippincott 1901 Cambridger Dr 48503  |Clothier ~  John |x | F x|
# 2088) =~ | = 2 JwoicasmEwN 00 [ © fcAtHoun @0 fear 000000 O [ 0} 00 0Kk
# 208910/6/2015  [saginawst ~  [1901E2ndst =~ =~ =~ = == 48503 = [Mareela === === [Franco 00000 fx |x 000 @ Ix
# 2090|10/7/2015  [SaginawSt.  [1901 Monteith St 48504 [willam = fcanmoy 000 fx | 000000 x 00| 00000
# 20] = | = Jio1pingree = === Jass03 =~ fAlexander == 0 [Marvin 000 I | 000000 000 Jx 0
# 202/ @@= | 2= [1901ROSELAWN = ==Z2Z=Z2Z2Z2= Ja8so4  fcooPeR 02020 [ANNETTA 00 Ix | 00000] 000 x
# 2003 = | = [i01Senecast 2220222 Jasso4  [Bailey =00 [kathy 0000000 fx |x 0000 Jx | @00
# 2094]10/7/2015 _ |Lippincott 1901 Shamruck Ln. 48504  [Harper =~ =~ christne = 0000 fx | 00000 @000 |x
# 2095[10/7/2015 _ |Lippincott 1901 Stevenson St. 48504  [willams = fcavin 0 fx | 000000 @000 ]x
# 2096/10/6/2015 _ |Lippincott 1901Tebost ~ ~  [48503  |pye == 02000 say 0000000 |x | 0000f 000k
# 2097|10/12/2015 fclioRd ~ [1901WelchBvd 48504  [Robinson =~~~ [Paulete = 0000 fx | 00000 @ |x
# 2008 = [ @ [1901 Woodslea #4 48507  [Bel = 0200 [kevin 0000 fx | 00000 ] 0000
# 20909 @ | = [1901 Woodslea Dr. Apt. 8 48507  [shaw ~~  [peirdre 0000 fx |x 0 Jx ] @00
# 21000 @ | = [1902AdamsAve === === Jassos = [Garrison = 00 [Roslyn 0000000k | 00000 Jx 0| 0000
# 21004/ @ | 0 Jw02Barksst =~ = 222 Ja8s03  fFieds = 02 franay 000 fx @ |x 000 Jx | @00
# 2102l @@= | 2@ [1902Briarwood = 2222 Ja8s07  [Freeman === |Geraldine = fx |x = Jx |
# 2103/10/6/2015 _ |Lippincott 1902 Carmenbrook Place 48507  [Reyes = [Reardo 0000 fx | 000 00 x
# 210f @ | 2 1902 Gilmartin St 48503  fperkins 0 fune 0000 fx | 000000k 0] 00000
# 2005 = | = [1902NBallenger =~ === 48504  fTucker == == == [Michele = fx | 000J @00 Jx
# 2106/10/7/2015 _ |Lippincott 1902 Park Forest Dr 48507  [Dukes == == fGlora 000 fx | 000000 000 ]x
# 2107|10/9/2015 |Lippincott 1902 S Franklin Ave 48503  fsmith = 00 fwle 0 fx | 0000000 000 |x
# 2108 @~ | = 2= [1902wgenesee == ZZ2Z202Z2Z=Z=<= 48504  fwatson == =2 [sandra 000000 }x | 00000J @00 Jx
# 2109 == | = [1902 WHobsonAve 48504  [Hamlet = fpinkle 00000 fx | 00000 @00 ]x
# 21100 = | 2 [i902welchBwd. =~ = = = = 48504  fwison =~ === |Sharon 000000 fx |x 000 00 |x
# 2111) 2@ 2 | = ]1902 Woodslea Dr. Apt. 1 48507  [speman =~ === [Keniesha = 000 fx | 00000 @000 |x
# 2112l @@ | 0000 [1903Jolietst 2= Jasso4  fAnderson == 2 fquayona 00000 fx |x 00 Jx | 0
# 2113[10/6/2015  [saginawSt  [1903 Laurel Oak Dr 48507  [Barmett =~ = = [Robet = 0000 fx | 000000 000X 0
# 2114f @ | = [1903 Laurel OakDr. 48507  [Barmett =~ = =2 [Robet = 0000 fx | 00000 000 x
# 2115 |  ]1903 MissouriAve 48506  kely ~  [Bamy 0 |x [ 0 ]x |
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# complaints 35 35
#
#
#
#
#
#
# billing rules 2 4
#
# meap 33 33
#
#
#
#
# gas choice 13 33
#
# 262
#
#
#
#
#
#
#
#
#
#
# 1126 |frog season
#
# 1127 lroutcreeks 0000000000000
# 1128 |silver bassewn 0000000000000
# 112 |fisheepot =~ 0000000000000
# 1130 |@lam@z00 0000000000000
# 1131 land usepermtt 0000000000000
#
# | 1132 [fine for no fishing license
#
#
#
# 1133 |stoneycreek
# 1134 |state park sticker
#
# | 1135 [free fishing days
# | 1136 |duck lake calhoun county
#
# | 1137 |garlic mustard plant
#
# 1138 lgarpike
# | 1139 [trail permit cost
# 1140 |greenfake
#
# 1141 |watercraft registration
# | 1142 |resident fishing license
#
#
#
#
#
#
#
# | 1146 |horseshoe lake
# 1147 [recordfish
# 1148 [tree planting
#
# pj hoffmaster state park
#
# 1s2 fcampfires
# 11-3 lalewife
# 1154 fcopper
# | 1155 |pipestone lake
#
#
#
#
#
# 160 loowseasson 0000000000000
# ue1 |boatingsafety 0000000000000
# ue2|beves 0000000000000
# 1163 |wolfhunt eesuts 0000000000000
#
# | 1164 |public boat launch directory
#
#
#
# 165 [lakeorion 00000
# 166 |munisiogei
# | 1167 |spring turkey guide
# 168 lgobles 0000000
# 169 |woodeock 000000
#  1y0 |Aatheadcatsh
#
#
#
#
#
#
#
#
#
#
# 9. DEPARTMENT OF CORRECTIONS, IONIA — Riverside Southern Region Offices
# — Heating System Boiler Study
# File No. 472/11032.DCS - Index No. 43670
#
# That the contract for professional services with Progressive AE, Grand Rapids,
# be increased $57,970.00
#
# Purpose/Business Case
#
# The purpose of this modification is to provide professional architectural/engineering
# services for development of construction bidding documents and construction
# administration to implement the recommendations from the recently completed heating
# system study. The completed study confirms relocation and repurposing of six existing
# hot water boilers within the remaining Riverside Southern Region Facilities will reduce
# operating costs for Department of Corrections.
#
# Benefit
#
# The State will benefit from this contract by having professionally prepared contract
# documents for the competitive bid process, and contract administration services through
# construction.
#
# Funding Source
#
# 100% Agency Operating Funds
#
# Commitment
#
# The professional services contract modification will be paid on an hourly/direct payroll
# basis times a multiplier plus reimbursables. The amount of the contract is within the
# authorized budget.
#
# Risk Assessment
#
# Failure to approve this contract will result in the State not obtaining the documents
# required for the competitive bidding process.
#
# 10. DEPARTMENT OF ENVIRONMENTAL QUALITY, MANCELONA — Tar Lake Site
# — Bio-Sparge System Improvements
# File No. 761/10324.BDH - Index No. 44081
#
# That the contract for professional services with MACTEC Engineering and
# Consulting of Michigan, Inc., Novi, be increased $14,588.00
#
# Purpose/Business Case
#
# The purpose of this modification is to provide for continued operation of the bio-sparge
# remediation system for an additional seven months. This site was a superfund site and
# the principal contaminants are creosote and similar wood preservatives. This change
# order will provide for additional site visits by the professional; pay for the additional
# electric power required to operate the bio-sparge remediation system; provide for a
# contingency for repair of the air compressor; and move the date of completion to April
# 15, 2012.
#
# Benefit
#
# The State will benefit by the removal of additional contamination from this site.
#
# Page 90 of 104

# %%
DateTimeRegex = {'weekday month yearOrday yearORday hours:mins AMorPM':'\\b[A-Za-z]+\s+[A-Za-z]+\s+\d+\s+\d+\s+\d+\:\d+\s+[A-Z]+\\b',
                 'weekday month yearORday yearORday hours:mins:secs AMorPM':'\\b[A-Za-z]+\s+[A-Za-z]+\s+\d+\s+\d+\s+\d+\:\d+\:\d+\s+[A-Z]+\\b',
    'yearORmonthORday-yearORmonthORday-yearORmonthORday:hours:mins:secs':'\\b\d+\-\d+\-\d+\:\d+\:\d+\:\d+\\b',
             'yearORmonthORday/yearORmonthORday/yearORmonthORday:hours:mins:secs':'\\b\d+\/\d+\/\d+\:\d+\:\d+\:\d+\\b',
             'yearORmonthORday-yearORmonthORday-yearORmonthORday-hours.mins.secs.millisecs':'\\b\d+\-\d+\-\d+\-\d+\.\d+\.\d+\.\d+\-\d+\\b',
             'yearORmonthORday/yearORmonthORday/yearORmonthORday-hours.mins.secs.millisecs':'\\b\d+\/\d+\/\d+\-\d+\.\d+\.\d+\.\d+\-\d+\\b',
             'yearORmonthORday-yearORmonthORday-yearORmonthORday-hours.mins.secs':'\\b\d+\-\d+\-\d+\-\d+\.\d+\.\d+\\b',
             'yearORmonthORday/yearORmonthORday/yearORmonthORday-hours.mins.secs':'\\b\d+\/\d+\/\d+\-\d+\.\d+\.\d+\\b',
             'yearORmonthORday-yearORmonthORday-yearORmonthORdayThours:mins:secs.millisecs':'\\b\d+\-\d+\-\d+[A-Za-z]+\d+\:\d+\:\d+\.\w+\\b',
             'yearORmonthORday-yearORmonthORday-yearORmonthORdayThours:mins:secs+millisecs':'\\b\d+\-\d+\-\d+[A-Za-z]+\d+\:\d+\:\d+\+\d+\\b',
             'yearORmonthORday-yearORmonthORday-yearORmonthORdayThours:mins:secs*millisecs':'\\b\d+\-\d+\-\d+[A-Za-z]+\d+\:\d+\:\d+\*\d+\+\d+\\b',
             'yearORmonthORday-yearORmonthORday-yearORmonthORday*hours:mins:secs:millisecs':'\\b\d+\-\d+\-\d+\*\d+\:\d+\:\d+\:\d+\\b',
             'yearORmonthORday-yearORmonthORday-yearORmonthORday*hours:mins:secs':'\\b\d+\-\d+\-\d+\*\d+\:\d+\:\d+\\b',
             'yearORmonthORday-yearORmonthORday-yearORmonthORdayThours:mins:secs':'\\b\d+\-\d+\-\d+[A-Za-z]+\d+\:\d+\:\d+\\b',
             'yearORmonthORday-yearORmonthORday-yearORmonthORday hours:mins:secs.millisecs':'\\b\d+\-\d+\-\d+\s+\d+\:\d+\:\d+\.\w+\\b',
             'yearORmonthORday/yearORmonthORday/yearORmonthORday hours:mins:secs:millisecs':'\\b\d+\/\d+\/\d+\s+\d+\:\d+\:\d+\:\w+\\b',
             'yearORmonthORday-yearORmonthORday-yearORmonthORday hours:mins:secs AMorPM':'\\b\d+\-\d+\-\d+\s+\d+\:\d+\:\d+\s+[A-Z]+\\b',
             'yearORmonthORday-yearORmonthORday-yearORmonthORday hours:mins:secs':'\\b\d+\-\d+\-\d+\s+\d+\:\d+\:\d+\\b',
             'yearORmonthORday/yearORmonthORday/yearORmonthORday hours:mins:secs AMorPM':'\\b\d+\/\d+\/\d+\s+\d+\:\d+\:\d+\s+[A-Z]+\\b',
             'yearORmonthORday/yearORmonthORday/yearORmonthORday hours:mins:secs':'\\b\d+\/\d+\/\d+\s+\d+\:\d+\:\d+\\b',
            'yearORmonthORday/yearORmonthORday/yearORmonthORday-hours:mins':'\\b\d+\/\d+\/\d+\-\d+\.\d+\\b',
            'yearORmonthORday-yearORmonthORday-yearORmonthORday-hours:mins':'\\b\d+\-\d+\-\d+\-\d+\.\d+\\b',
            'yearORmonthORday/yearORmonthORday/yearORmonthORday:hours:mins':'\\b\d+\/\d+\/\d+\:\d+\:\d+\\b',
            'yearORmonthORday-yearORmonthORday-yearORmonthORdayThours:mins':'\\b\d+\-\d+\-\d+[A-Za-z]+\d+\:\d+\\b',
            'yearORmonthORday-yearORmonthORday-yearORmonthORday*hours:mins':'\\b\d+\-\d+\-\d+\*\d+\:\d+\\b',
            'yearORmonthORday/yearORmonthORday/yearORmonthORday hours:mins':'\\b\d+\/\d+\/\d+\s+\d+\:\d+\\b',
            'yearORmonthORday/yearORmonthORday/yearORmonthORday hours:mins AMorPM':'\\b\d+\/\d+\/\d+\s+\d+\:\d+\s+[A-Za-z]+\\b',
            'yearORmonthORday-yearORmonthORday-yearORmonthORday hours:mins':'\\b\d+\-\d+\-\d+\s+\d+\:\d+\\b',
            'yearORmonthORday-yearORmonthORday-yearORmonthORday hours:mins AMorPM':'\\b\d+\-\d+\-\d+\s+\d+\:\d+\s+[A-Za-z]\\b',
             'yearORday/month/yearORday:hours:mins:secs AMorPM':'\\b\d+\/[A-Za-z]+\/\d+\:\d+\:\d+\:\d+\s+[A-Z]+\\b',
             'yearORday/month/yearORday:hours:mins:secs':'\\b\d+\/[A-Za-z]+\/\d+\:\d+\:\d+\:\d+\\b',
             'yearORday-month-yearORday:hours:mins:secs AMorPM':'\\b\d+\-[A-Za-z]+\-\d+\:\d+\:\d+\:\d+\s+[A-Z]+\\b',
             'yearORday-month-yearORday:hours:mins:secs':'\\b\d+\-[A-Za-z]+\-\d+\:\d+\:\d+\:\d+\\b',
             'month/yearORday/yearORday:hours:mins:secs AMorPM':'\\b[A-Za-z]+\/\d+\/\d+\:\d+\:\d+\:\d+\s+[A-Z]+\\b',
             'month/yearORday/yearORday:hours:mins:secs':'\\b[A-Za-z]+\/\d+\/\d+\:\d+\:\d+\:\d+\\b',
             'month-yearORday-yearORday:hours:mins:secs AMorPM':'\\b[A-Za-z]+\-\d+\-\d+\:\d+\:\d+\:\d+\s+[A-Z]+\\b',
             'month-yearORday-yearORday:hours:mins:secs':'\\b[A-Za-z]+\-\d+\-\d+\:\d+\:\d+\:\d+\\b',
             'yearORday/month/yearORday hours:mins:secs AMorPM':'\\b\d+\/[A-Za-z]+\/\d+\s+\d+\:\d+\:\d+\s+[A-Z]+\\b',
             'yearORday/month/yearORday hours:mins:secs':'\\b\d+\/[A-Za-z]+\/\d+\s+\d+\:\d+\:\d+\\b',
             'yearORday-month-yearORday hours:mins:secs AMorPM':'\\b\d+\-[A-Za-z]+\-\d+\s+\d+\:\d+\:\d+\s+[A-Z]+\\b',
             'yearORday-month-yearORday hours:mins:secs':'\\b\d+\-[A-Za-z]+\-\d+\s+\d+\:\d+\:\d+\\b',
             'month/yearORday/yearORday hours:mins:secs AMorPM':'\\b[A-Za-z]+\/\d+\/\d+\s+\d+\:\d+\:\d+\s+[A-Z]+\\b',
             'month/yearORday/yearORday hours:mins:secs':'\\b[A-Za-z]+\/\d+\/\d+\s+\d+\:\d+\:\d+\\b',
             'month-yearORday-yearORday hours:mins:secs AMorPM':'\\b[A-Za-z]+\-\d+\-\d+\s+\d+\:\d+\:\d+\s+[A-Z]+\\b',
             'month-yearORday-yearORday hours:mins:secs':'\\b[A-Za-z]+\-\d+\-\d+\s+\d+\:\d+\:\d+\\b',
             'yearORday month yearORday hours:mins:secs.millisecs':'\\b\d+\s+[A-Za-z]+\s+\d+\s+\d+\:\d+\:\d+\.\d+\\b',
             'month dayORyear hours:mins:secs +millisecs dayORyear':'\\b[A-Za-z]+\s+\d+\s+\d+\:\d+\:\d+\s+\+\d+\s+\d+\\b',
             'month dayORyear hours:mins:secs dayORyear':'\\b[A-Za-z]+\s+\d+\s+\d+\:\d+\:\d+\s+\d+\\b',
             'month dayORyear dayORyear hours:mins:secs AMorPM':'\\b[A-Za-z]+\s+\d+\s+\d+\s+\d+\:\d+\:\d+\s+[A-Z]+\\b',
             'month dayORyear dayORyear hours:mins:secs':'\\b[A-Za-z]+\s+\d+\s+\d+\s+\d+\:\d+\:\d+\\b',
             'month dayORyear hours:mins:secs +millisecs':'\\b[A-Za-z]+\s+\d+\s+\d+\:\d+\:\d+\s+\+\d+\\b',
             'dayORyear month dayORyear hours:mins:secs':'\\b\d+\s+[A-Za-z]+\s+\d+\s+\d+\:\d+\:\d+\\b',
             'month dayORyear hours:mins:secs':'\\b[A-Za-z]+\s+\d+\s+\d+\:\d+\:\d+\\b',
             'yearORmonthORday/yearORmonthORday/yearORmonthORday':'\\b\d+\/\d+\/\d+\*\d+\:\d+\:\d+\\b',
'yearORday/month/yearORday:hours:mins AMorPM':'\\b\d+\/[A-Za-z]+\d+\:\d+\:\d+\s+[A-Za-z]+\\b',
'yearORday/month/yearORday:hours:mins':'\\b\d+\/[A-Za-z]+\/\d+\:\d+\:\d+\\b',
'yearORday-month-yearORday:hours:mins AMorPM':'\\b\d+\-[A-Za-z]+\-\d+\:\d+\:\d+\s+[A-Za-z]+\\b',
'yearORday-month-yearORday:hours:mins':'\\b\d+\-[A-Za-z]+\-\d+\:\d+\:\d+\\b',
'month-yearORday-yearORday:hours:mins AMorPM':'\\b[A-Za-z]+\-\d+\-\d+\:\d+\:\d+\s+[A-Za-z]+\\b',
'month-yearORday-yearORday:hours:mins':'\\b[A-Za-z]+\-\d+\-\d+\:\d+\:\d+\\b',
'month/yearORday/yearORday:hours:mins AMorPM':'\\b[A-Za-z]+\/\d+\/\d+\:\d+\:\d+\s+[A-Za-z]+\\b',
'month/yearORday/yearORday:hours:mins':'\\b[A-Za-z]+\/\d+\/\d+\:\d+\:\d+\\b',
'yearORday/month/yearORday hours:mins AMorPM':'\\b\d+\/[A-Za-z]+\/\d+\s+\d+\:\d+\s+[A-Za-z]+\\b',
'yearORday/month/yearORday hours:mins':'\\b\d+\/[A-Za-z]+\/\d+\s+\d+\:\d+\\b',
'yearORday-month-yearORday hours:mins AMorPM':'\\b\d+\-[A-Za-z]+\-\d+\s+\d+\:\d+\s+[A-Za-z]+\\b',
'yearORday-month-yearORday hours:mins':'\\b\d+\-[A-Za-z]+\-\d+\s+\d+\:\d+\\b',
'month/yearORday/yearORday hours:mins AMorPM':'\\b[A-Za-z]\/\d+\/\d+\s+\d+\:\d+\s+[A-Za-z]+\\b',
'month/yearORday/yearORday hours:mins':'\\b[A-Za-z]\/\d+\/\d+\s+\d+\:\d+\\b',
'month-yearORday-yearORday hours:mins AMorPM':'\\b[A-Za-z]+\-\d+\-\d+\s+\d+\:\d+\s+[A-Za-z]+\\b',
'month-yearORday-yearORday hours:mins':'\\b[A-Za-z]+\-\d+\-\d+\s+\d+\:\d+\\b',
'year month day hours:mins':'\\b\d+\s+[A-Za-z]+\s+\d+\s+\d+\:\d+\\b',
'month day hours:mins year':'\\b[A-Za-z]+\s+\d+\s+\d+\:\d+\s+\d+\\b',
'month day hours:mins':'\\b[A-Za-z]+\s+\d+\s+\d+\:\d+\\b',
'month day year hours:mins AMorPM':'\\b[A-Za-z]+\s+\d+\s+\d+\s+\d+\:\d+\s+[A-Za-z]+\\b',
'month day year hours:mins':'\\b[A-Za-z]+\s+\d+\s+\d+\s+\d+\:\d+\\b',
'on weekday, month day, year at hours:mins AMorPM':'\\b[a-z]+\s+[A-Za-z]+\s+[A-Za-z]+\s+\d+\s+\d+\s+[a-z]+\s+\d+\:\d+\s+[A-Za-z]+\\b',
'on month day, year, at hours:mins AMorPM':'\\b[a-z]+\s+[A-Za-z]+\s+\d+\s+\d+\s+[a-z]+\s+\d+\:\d+\s+[A-Za-z]+\\b'}

# %%
import urllib
import os
import re

# %%
def preprocess(x):
    x = x.replace('\t',' ')
    x = x.replace('\n',' ')
    x = x.replace('(',' ')
    x = x.replace(')',' ')
    x = x.replace('[',' ')
    x = x.replace(']',' ')
    x = x.replace('{',' ')
    x = x.replace('}',' ')
    x = x.replace(',',' ')
    x = x.replace('"','')
    x = x.replace("'",'')
    return(x)

# %%
reg = '|'.join(DateTimeRegex.values())

# %%
def DateTimeExtractor(x):
    x = preprocess(x)
    DT = re.findall(reg,x)
    return(DT)

# %%
stamps = DateTimeExtractor(text_sample)

# %%
print(stamps)
# Out:
# ['10/19/2015 08:30', '10/26/2015 15:42', '10/30/2015 8:55', '10/23/2014 08:50', '10/24/2014 08:25', '10/27/2014 12:07', 'Thursday  July 09  2015 4:53:41 PM', 'Thursday  July 09  2015 4:48 PM', 'Wednesday  January 27  2016 4:28:44 PM', 'Wednesday  January 27  2016 4:16 PM', 'Monday  October 12  2015 12:53 PM', 'Monday  October 12  2015 12:53 PM', 'Monday  February 22  2016 10:46:38 AM', 'Wednesday  January 27  2016 8:42 AM', '11/14/2015 09:21', '11/16/2015 07:16', '12/10/2015 2:59', 'Tuesday  January 26  2016 11:16 AM', 'Tuesday  January 26  2016 10:48 AM', 'Thursday  December 03  2015 3:39 PM', 'Friday  January 15  2016 8:47 AM', 'Thursday  February 26  2015 10:25 AM']
